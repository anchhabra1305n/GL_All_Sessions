# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
import os
os.chdir('/Users/anchhabra/OneDrive - PayPal/Personal_Data_Transfer/GLA/GLA_Live_Session/Python_Masterclass')
# /Users/anchhabra/OneDrive - PayPal/Personal_Data_Transfer/GLA/GLA_Live_Session/Python_Masterclass

# %%
os.getcwd()
# Out:
# '/Users/anchhabra/OneDrive - PayPal/Personal_Data_Transfer/GLA/GLA_Live_Session/Python_Masterclass'

# %% [markdown]
# ### Set the default seaborn style for our plots
# seaborn default settings

# %%
sns.set()

# %%
### Load and View the Matches Data
df = pd.read_csv('Matches.csv')

# %%
#view top few rows
df.head(10)
# Out:
#    id  season        city        date                  team1  \
# 0  60    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1  61    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2  62    2008       Delhi  19-04-2008       Rajasthan Royals
# 3  63    2008      Mumbai  20-04-2008         Mumbai Indians
# 4  64    2008     Kolkata  20-04-2008        Deccan Chargers
# 5  65    2008      Jaipur  21-04-2008        Kings XI Punjab
# 6  66    2008   Hyderabad  22-04-2008        Deccan Chargers
# 7  67    2008     Chennai  23-04-2008    Chennai Super Kings
# 8  68    2008   Hyderabad  24-04-2008        Deccan Chargers
# 9  69    2008  Chandigarh  25-04-2008        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
#view bottom few rows
df.tail()
# Out:
#         id  season           city        date                  team1  \
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
# shape of the dataset
df.shape
# Out:
# (756, 18)

# %%
#information about data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
#variable description
df.describe(include='all')
# Out:
#                   id       season    city        date           team1  \
# count     756.000000   756.000000     749         756             756
# unique           NaN          NaN      32         546              15
# top              NaN          NaN  Mumbai  07-04-2012  Mumbai Indians
# freq             NaN          NaN     101           2             101
# mean     1792.178571  2013.444444     NaN         NaN             NaN
# std      3464.478148     3.366895     NaN         NaN             NaN
# min         1.000000  2008.000000     NaN         NaN             NaN
# 25%       189.750000  2011.000000     NaN         NaN             NaN
# 50%       378.500000  2013.000000     NaN         NaN             NaN
# 75%       567.250000  2016.000000     NaN         NaN             NaN
# max     11415.000000  2019.000000     NaN         NaN             NaN
#
#                               team2     toss_winner toss_decision  result  \
# ...

# %% [markdown]
# As we have few ordinal fields with ratings provided in numeric form, let us first convert them to object form

# %%
df.season = df.season.astype('object')
df.dl_applied = df.dl_applied.astype('object') ### Duckworth Lewis method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    object
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# ### Missing Data Treatment

# %%
# missing values finding
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
df1.shape
# Out:
# (118, 18)

# %%
# Summary of games won by each team per season
summary_df = df[['season','winner']].groupby(['season','winner']).size().reset_index(name = "No.of games won")
summary_df.head(10)
# Out:
#    season                       winner  No.of games won
# 0    2008          Chennai Super Kings                9
# 1    2008              Deccan Chargers                2
# 2    2008             Delhi Daredevils                7
# 3    2008              Kings XI Punjab               10
# 4    2008        Kolkata Knight Riders                6
# 5    2008               Mumbai Indians                7
# 6    2008             Rajasthan Royals               13
# 7    2008  Royal Challengers Bangalore                4
# 8    2009          Chennai Super Kings                8
# 9    2009              Deccan Chargers                9

# %%
# teams_per_season = df.groupby('season')['winner'].value_counts()
# teams_per_season

# %%
# year = 2008
# win_per_season_df = pd.DataFrame(columns=['year', 'team', 'wins'])
# for items in teams_per_season.iteritems():    
#     if items[0][0]==year:
#         print(items)
#         win_series = pd.DataFrame({
#             'year': [items[0][0]],
#             'team': [items[0][1]],
#             'wins': [items[1]]
#         })
#         win_per_season_df = win_per_season_df.append(win_series)
#         year += 1

# %%
# win_per_season_df

# %%
# #plot winner by year
# fig_dims=(20,20)
# fig=plt.subplots(figsize=fig_dims)
# sns.barplot('wins','team',hue='year',data=win_per_season_df)

# %%
#plot winner by year
fig_dims=(20,20)
fig=plt.subplots(figsize=fig_dims)
sns.barplot('No.of games won','winner',
            hue='season',data=summary_df)
# Out:
# /Users/anchhabra/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No.of games won', ylabel='winner'>

# %%
pd.crosstab(df.season, df.winner)
# Out:
# winner  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# season
# 2008                      9                2               0
# 2009                      8                9               0
# 2010                      9                8               0
# 2011                     11                6               0
# 2012                     10                4               0
# 2013                     12                0               0
# 2014                     10                0               0
# 2015                     10                0               0
# 2016                      0                0               0
# 2017                      0                0               0
# 2018                     11                0               0
# 2019                     10                0              10
#
# winner  Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# season
# 2008                   7              0               10
# ...

# %%
venue_ser = df['venue'].value_counts()
venue_ser
### Inference - Eden Gardens is the most common venue
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# ...

# %%
venue_df = pd.DataFrame(columns=['venue', 'matches'])
for items in venue_ser.iteritems():
    temp_df = pd.DataFrame({
        'venue':[items[0]],
        'matches':[items[1]]
    })
    venue_df = venue_df.append(temp_df, ignore_index=True)

# %%
fig_dims = (35, 20)
fig = plt.subplots(figsize=fig_dims)
sns.barplot(x='matches', y='venue', data=venue_df)
# Out:
# <AxesSubplot:xlabel='matches', ylabel='venue'>

# %%
df.team1.value_counts()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
df.team2.value_counts()
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
df.toss_winner.value_counts()
## Inference Mumbai Indians won toss maximum number of times
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
#toss_decision
df.toss_decision.value_counts()
## Inference- Most number of times toss_decision was to field rather than bat.
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
fig_dims = (35, 10)
fig = plt.subplots(figsize=fig_dims)
sns.set(font_scale=2)
chart=sns.countplot(x='season', hue='toss_decision', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
## Trend was different in initial years
# Out:
# [Text(0, 0, '2008'),
#  Text(1, 0, '2009'),
#  Text(2, 0, '2010'),
#  Text(3, 0, '2011'),
#  Text(4, 0, '2012'),
#  Text(5, 0, '2013'),
#  Text(6, 0, '2014'),
#  Text(7, 0, '2015'),
#  Text(8, 0, '2016'),
#  Text(9, 0, '2017'),
#  Text(10, 0, '2018'),
#  Text(11, 0, '2019')]

# %%
pd.crosstab(df.season, df.toss_decision, margins=True)
# Out:
# toss_decision  bat  field  All
# season
# 2008            26     32   58
# 2009            35     22   57
# 2010            39     21   60
# 2011            25     48   73
# 2012            37     37   74
# 2013            45     31   76
# 2014            19     41   60
# 2015            25     34   59
# 2016            11     49   60
# 2017            11     48   59
# 2018            10     50   60
# 2019            10     50   60
# All            293    463  756

# %%
fig_dims = (35, 10)
fig = plt.subplots(figsize=fig_dims)
sns.set(font_scale=2)
chart=sns.countplot(x='winner', hue='toss_decision', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Kolkata Knight Riders'),
#  Text(0, 0, 'Chennai Super Kings'),
#  Text(0, 0, 'Delhi Daredevils'),
#  Text(0, 0, 'Royal Challengers Bangalore'),
#  Text(0, 0, 'Rajasthan Royals'),
#  Text(0, 0, 'Kings XI Punjab'),
#  Text(0, 0, 'Deccan Chargers'),
#  Text(0, 0, 'Mumbai Indians'),
#  Text(0, 0, 'Pune Warriors'),
#  Text(0, 0, 'Kochi Tuskers Kerala'),
#  Text(0, 0, 'Sunrisers Hyderabad'),
#  Text(0, 0, 'Rising Pune Supergiants'),
#  Text(0, 0, 'Gujarat Lions'),
#  Text(0, 0, 'Rising Pune Supergiant'),
#  Text(0, 0, 'Delhi Capitals')]

# %%
pd.crosstab(df.winner, df.toss_decision, margins=True)
# Out:
# toss_decision                bat  field  All
# winner
# Chennai Super Kings           52     48  100
# Deccan Chargers               14     15   29
# Delhi Capitals                 2      8   10
# Delhi Daredevils              29     38   67
# Gujarat Lions                  2     11   13
# Kings XI Punjab               21     61   82
# Kochi Tuskers Kerala           0      6    6
# Kolkata Knight Riders         35     57   92
# Mumbai Indians                45     64  109
# Pune Warriors                  9      3   12
# Rajasthan Royals              34     41   75
# Rising Pune Supergiant         0     10   10
# Rising Pune Supergiants        2      3    5
# Royal Challengers Bangalore   26     58   84
# Sunrisers Hyderabad           21     37   58
# All                          292    460  752

# %%
#result
df.result.value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
#winner
df.winner.value_counts()
## Mumbai Indians have won maximum number of matches followed by Chennai Super Kings
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
#win_by_runs
df.win_by_runs.describe()
# Out:
# count    756.000000
# mean      13.283069
# std       23.471144
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       19.000000
# max      146.000000
# Name: win_by_runs, dtype: float64

# %%
#win_by_wickets
df.win_by_wickets.describe()
# Out:
# count    756.000000
# mean       3.350529
# std        3.387963
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        6.000000
# max       10.000000
# Name: win_by_wickets, dtype: float64

# %%
sns.boxplot(x='win_by_runs',data=df)

# %%
sns.boxplot(x='win_by_wickets',data=df)

# %%
df.city.value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Mohali             10
# Rajkot             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Abu Dhabi           7
# Port Elizabeth      7
# Cape Town           7
# Cuttack             7
# Ranchi              7
# Raipur              6
# Sharjah             6
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df.season.value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
fig_dims = (35, 10)
fig = plt.subplots(figsize=fig_dims)
sns.set(font_scale=2)
chart=sns.countplot(x='city', hue='toss_decision', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Bangalore'),
#  Text(0, 0, 'Chandigarh'),
#  Text(0, 0, 'Delhi'),
#  Text(0, 0, 'Mumbai'),
#  Text(0, 0, 'Kolkata'),
#  Text(0, 0, 'Jaipur'),
#  Text(0, 0, 'Hyderabad'),
#  Text(0, 0, 'Chennai'),
#  Text(0, 0, 'Cape Town'),
#  Text(0, 0, 'Port Elizabeth'),
#  Text(0, 0, 'Durban'),
#  Text(0, 0, 'Centurion'),
#  Text(0, 0, 'East London'),
#  Text(0, 0, 'Johannesburg'),
#  Text(0, 0, 'Kimberley'),
#  Text(0, 0, 'Bloemfontein'),
#  Text(0, 0, 'Ahmedabad'),
#  Text(0, 0, 'Cuttack'),
#  Text(0, 0, 'Nagpur'),
#  Text(0, 0, 'Dharamsala'),
#  Text(0, 0, 'Kochi'),
#  Text(0, 0, 'Indore'),
#  Text(0, 0, 'Visakhapatnam'),
#  Text(0, 0, 'Pune'),
#  Text(0, 0, 'Raipur'),
#  Text(0, 0, 'Ranchi'),
#  Text(0, 0, 'Abu Dhabi'),
#  Text(0, 0, 'Sharjah'),
#  Text(0, 0, 'Rajkot'),
#  Text(0, 0, 'Kanpur'),
#  Text(0, 0, 'Mohali'),
#  Text(0, 0, 'Bengaluru')]
