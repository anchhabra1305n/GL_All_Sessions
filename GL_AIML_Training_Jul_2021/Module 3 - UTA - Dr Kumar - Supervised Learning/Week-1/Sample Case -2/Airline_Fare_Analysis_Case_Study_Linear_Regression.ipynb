# %% [markdown]
# # Description:
# Airfares and passengers for U.S. Domestic Routes
# for 4th Quarter of 2002.

# %% [markdown]
# # Variables/Columns
#
# City1   1-3
#
# City2   5-7
#
# Average Fare    11-17
#
# Distance      20-23
#
# Average weekly passengers   26-33
#
# market leading airline    36-37
#
# market share     40-45
#
# Average fare    48-54
#
# Low price airline   57-58
#
# market share    61-66
#
# price     69-75

# %% [markdown]
# # Source:
# U.S. Department of Transportation

# %% [markdown]
# # 1. Reading Source File and Checking Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading source file
file=pd.read_csv("http://users.stat.ufl.edu/~winner/data/airq402.dat", sep='\s+'  , engine='python')

# %%
# Adding colunm names as mentioned in data file
file.columns = ['City1', 'City2', 'Average Flight Fare', 'Distance','Average Weekly Passengers','Market Leading Airline (MLA)',
               'Market Share MLA', 'Average MLA Fare', 'Low Price Airline (LPA)', 'Market Share LPA', 'Average LPA Fare']

# %%
file.head()
# Out:
#   City1 City2  Average Flight Fare  Distance  Average Weekly Passengers  \
# 0   CAK   MCO               122.47       860                     276.84
# 1   ALB   ATL               214.42       852                     215.76
# 2   ALB   BWI                69.40       288                     606.84
# 3   ALB   ORD               158.13       723                     313.04
# 4   ALB   FLL               135.17      1204                     199.02
#
#   Market Leading Airline (MLA)  Market Share MLA  Average MLA Fare  \
# 0                           FL             75.10            123.09
# 1                           DL             78.89            223.98
# 2                           WN             96.97             68.86
# 3                           UA             39.79            161.36
# 4                           WN             40.68            137.97
#
#   Low Price Airline (LPA)  Market Share LPA  Average LPA Fare
# 0                      DL             17.23            118.94
# 1                      CO              2.77            167.12
# 2                      WN             96.97             68.86
# 3                      WN             15.34            145.42
# 4                      DL             17.09            127.69

# %% [markdown]
# # 2. Data Cleaning

# %%
# getting total number of rows and column in the dataframe
print(f" Shape of the dataframe = {file.shape}")
totalrows=file.shape[0]
print(f" Total number of rows in the dataset =  {totalrows}")
# Out:
#  Shape of the dataframe = (999, 11)
#  Total number of rows in the dataset =  999

# %%
# Checking Null colunms
file_nullcols = file.isnull().sum()
file_nullcols
# No null values are found
# Out:
# City1                           0
# City2                           0
# Average Flight Fare             0
# Distance                        0
# Average Weekly Passengers       0
# Market Leading Airline (MLA)    0
# Market Share MLA                0
# Average MLA Fare                0
# Low Price Airline (LPA)         0
# Market Share LPA                0
# Average LPA Fare                0
# dtype: int64

# %%
# Checking data type of each colunm to check if any type needs to be changed
file.dtypes
# Out:
# City1                            object
# City2                            object
# Average Flight Fare             float64
# Distance                          int64
# Average Weekly Passengers       float64
# Market Leading Airline (MLA)     object
# Market Share MLA                float64
# Average MLA Fare                float64
# Low Price Airline (LPA)          object
# Market Share LPA                float64
# Average LPA Fare                float64
# dtype: object

# %%
# Checking basic details of the data
file.describe()
# Out:
#        Average Flight Fare     Distance  Average Weekly Passengers  \
# count           999.000000   999.000000                 999.000000
# mean            163.424374  1057.502503                 672.527107
# std              55.371544   643.307320                 766.863056
# min              50.520000   108.000000                 181.410000
# 25%             126.025000   554.000000                 257.115000
# 50%             161.360000   919.000000                 404.780000
# 75%             197.435000  1455.000000                 770.265000
# max             401.230000  2724.000000                8950.760000
#
#        Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# count        999.000000        999.000000        999.000000        999.000000
# mean          60.118519        166.703233         34.515806        143.225285
# std           19.374859         62.666775         27.087067         47.241860
# min           17.680000         50.520000          1.060000         49.610000
# 25%           46.510000        124.120000         13.190000        113.825000
# 50%           59.060000        161.440000         26.120000        137.830000
# 75%           73.520000        203.105000         52.950000        168.540000
# max          100.000000        490.030000        100.000000        387.940000

# %%
# Mean of distance, Average Weekly Passengers, Market share is above median
#These prima facie seem to have outliers

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ## 3.1. Univariate Analysis

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Average Flight Fare')
sns.distplot(file['Average Flight Fare'],color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Distance')
sns.distplot(file['Distance'],color='blue')

# subplot 3l
plt.subplot(1, 3, 3)
plt.title('Average Weekly Passengers')
sns.distplot(file['Average Weekly Passengers'],color='red')

plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Average Flight Fare')
sns.boxplot(file['Average Flight Fare'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Distance')
sns.boxplot(file['Distance'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('Average Weekly Passengers')
sns.boxplot(file['Average Weekly Passengers'],orient='vertical',color='red')

plt.show()

# %% [markdown]
# ##### Most of the flight fare lie between 100 to 300 with some outliers
# ##### Average distance ranges between 500 to 2500
# ##### Most of the time Average Weekly Passenger numer is less than 2000 but there are large number of outliers

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 4, 1)
plt.title('Market Share MLA')
sns.distplot(file['Market Share MLA'],color='green')

# subplot 2
plt.subplot(1, 4, 2)
plt.title('Average MLA Fare')
sns.distplot(file['Average MLA Fare'],color='blue')

# subplot 3
plt.subplot(1, 4, 3)
plt.title('Market Share LPA')
sns.distplot(file['Market Share LPA'],color='red')

# subplot 4
plt.subplot(1, 4, 4)
plt.title('Average LPA Fare')
sns.distplot(file['Average LPA Fare'],color='red')


plt.figure(figsize=(20,6))
plt.subplot(1, 4, 1)
plt.title('Market Share MLA')
sns.boxplot(file['Market Share MLA'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 4, 2)
plt.title('Average MLA Fare')
sns.boxplot(file['Average MLA Fare'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 4, 3)
plt.title('Market Share LPA')
sns.boxplot(file['Market Share LPA'],orient='vertical',color='red')

# subplot 4
plt.subplot(1, 4, 4)
plt.title('Average LPA Fare')
sns.boxplot(file['Average LPA Fare'],orient='vertical',color='red')



plt.show()

# %% [markdown]
# ##### Average fare of both Market Leader and Low Price Airline range from 100 to 300 with some outliers
# ##### Market Leader has 40 to 80 percent market share on most routes
# ##### Lower Price airline has less than 40 percent market share on most of the routes

# %%
file.head()
# Out:
#   City1 City2  Average Flight Fare  Distance  Average Weekly Passengers  \
# 0   CAK   MCO               122.47       860                     276.84
# 1   ALB   ATL               214.42       852                     215.76
# 2   ALB   BWI                69.40       288                     606.84
# 3   ALB   ORD               158.13       723                     313.04
# 4   ALB   FLL               135.17      1204                     199.02
#
#   Market Leading Airline (MLA)  Market Share MLA  Average MLA Fare  \
# 0                           FL             75.10            123.09
# 1                           DL             78.89            223.98
# 2                           WN             96.97             68.86
# 3                           UA             39.79            161.36
# 4                           WN             40.68            137.97
#
#   Low Price Airline (LPA)  Market Share LPA  Average LPA Fare
# 0                      DL             17.23            118.94
# 1                      CO              2.77            167.12
# 2                      WN             96.97             68.86
# 3                      WN             15.34            145.42
# 4                      DL             17.09            127.69

# %%
# fig, ax = plt.subplots(figsize=(20,8))
# ax=sns.countplot(data = file, x= 'Market Leading Airline (MLA)') 

# for p in ax.patches: 
#     print(p)
    
#     ax.annotate(str((np.round(p.get_height()/len(file)*100,decimals=2)))+'%', 
#                 (p.get_x()+p.get_width()/2., p.get_height()), 
#                 ha='center', va='center', 
#                 xytext=(0, 10), 
#                 textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20,8))
width = len(file['Market Leading Airline (MLA)'].unique()) + 6
fig.set_size_inches(width , 8)
ax=sns.countplot(data = file, x= 'Market Leading Airline (MLA)') 

for p in ax.patches: 
    ax.annotate(str((np.round(p.get_height()/len(file)*100,decimals=2)))+'%', 
                (p.get_x()+p.get_width()/2., p.get_height()),
                ha='center', 
                va='center', 
                xytext=(0, 10),
                textcoords='offset points')

# %% [markdown]
# ##### WN followed by DL happens to be market leader airline on most of the routes

# %%
fig, ax = plt.subplots(figsize=(20,8))
width = len(file['Low Price Airline (LPA)'].unique()) + 6
fig.set_size_inches(width , 8)
ax=sns.countplot(data = file, x= 'Low Price Airline (LPA)') 

for p in ax.patches: 
    ax.annotate(str((np.round(p.get_height()/len(file)*100,decimals=2)))+'%', (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# %%
##### WN followed by DL happens to be the low price airline on most routes

# %% [markdown]
# ## 3.2. Bivariate Analysis

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = file.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col1 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col4 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col5 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col6 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col0 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col4 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col5 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row1_col6 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col3 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col5 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row2_col6 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col0 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col2 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col4 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col5 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col0 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col1 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col2 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col3 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row4_col6 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col1 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col2 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col3 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row5_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col0 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col1 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col3 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col4 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Flight Fare</th>        <th class="col_heading level0 col1" >Distance</th>        <th class="col_heading level0 col2" >Average Weekly Passengers</th>        <th class="col_heading level0 col3" >Market Share MLA</th>        <th class="col_heading level0 col4" >Average MLA Fare</th>        <th class="col_heading level0 col5" >Market Share LPA</th>        <th class="col_heading level0 col6" >Average LPA Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4level0_row0" class="row_heading level0 row0" >Average Flight Fare</th>
#                         <td id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col1" class="data row0 col1" >0.586869</td>
#                         <td id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col2" class="data row0 col2" >-0.126517</td>
#                         <td id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col3" class="data row0 col3" >-0.233805</td>
#                         <td id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col4" class="data row0 col4" >0.981448</td>
#                         <td id="T_0858cb0b_fcb5_11eb_b641_cc483a7791d4row0_col5" class="data

# %% [markdown]
# #### Average Flight fare is most corelated to fare of market leader and low performing flight

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1,2,1)
sns.boxplot(x = 'Market Leading Airline (MLA)', y = 'Average Flight Fare', data = file)
plt.subplot(1,2,2)
sns.boxplot(x = 'Low Price Airline (LPA)', y = 'Average Flight Fare', data = file)

# %% [markdown]
# ##### Most flights have comparable median flight fare with some having very low values
# ##### Flight fare of market leading airline and Low Price airline seem to fall in similar range

# %% [markdown]
# # 4. Multivariate Regression and Scatter Plot

# %% [markdown]
# ## 4.1. Scatter Plot

# %%
sns.pairplot(file, y_vars='Average Flight Fare', 
             x_vars=["Distance", "Average Weekly Passengers",
                     'Market Share MLA', 'Average MLA Fare',
                     'Market Share LPA','Average LPA Fare']
            )
plt.show()

# %% [markdown]
# ##### Average Flight fare is most corelated to fare of market leader and low performing flight with mild corelation with Distance as well

# %% [markdown]
# ##### Variabes need to be scaled before further analysis

# %% [markdown]
# ##### Transformation seems unnecessary as most data points don't show any clear trend with Average flight Fare.
# ##### Still checkking effect of log transformation on the data set

# %%
# Log Transformation of independent variables
D1 = np.log(file['Distance'])
D2 = np.log(file['Average Weekly Passengers'])
D3 = np.log(file['Market Share MLA'])
D4 = np.log(file['Average MLA Fare'])
D5 = np.log(file['Market Share LPA'])
D6 = np.log(file['Average LPA Fare'])

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 2, 1)
plt.title('Flight Fare vs Log(Distance)')
plt.scatter(D1, file['Average Flight Fare'])
plt.xlabel('Log(Distance)')
plt.ylabel('Flight Fare')

plt.figure(figsize=(20,6))
plt.subplot(1, 2, 2)
plt.title('Flight Fare vs Log(Average Weekly Passengers)')
plt.scatter(D2, file['Average Flight Fare'])
plt.xlabel('Log(Average Weekly Passengers)')
plt.ylabel('Flight Fare')


plt.show()

# %% [markdown]
# #### Given Transformation does'nt seem to be adding much value, going forth with raw data only

# %% [markdown]
# ## 4.2. Multi Linear Regression Model

# %%
# Dropping cities and Flight Name colunm as these are not actionable

# %%
file.drop(['City1'], axis = 1, inplace = True)
file.drop(['City2'], axis = 1, inplace = True)
file.drop(['Market Leading Airline (MLA)'], axis = 1, inplace = True)
file.drop(['Low Price Airline (LPA)'], axis = 1, inplace = True)

# %%
file.head()
# Out:
#    Average Flight Fare  Distance  Average Weekly Passengers  Market Share MLA  \
# 0               122.47       860                     276.84             75.10
# 1               214.42       852                     215.76             78.89
# 2                69.40       288                     606.84             96.97
# 3               158.13       723                     313.04             39.79
# 4               135.17      1204                     199.02             40.68
#
#    Average MLA Fare  Market Share LPA  Average LPA Fare
# 0            123.09             17.23            118.94
# 1            223.98              2.77            167.12
# 2             68.86             96.97             68.86
# 3            161.36             15.34            145.42
# 4            137.97             17.09            127.69

# %% [markdown]
# ###  4.2.1. Splitting Data into Training and Test

# %%
from sklearn.model_selection import train_test_split
np.random.seed(0)
file_train, file_test = train_test_split(file, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# ### 4.2.2. Rescaling the Features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns except the 'dummy' variables
vars = ['Average Flight Fare', 'Distance', 'Average Weekly Passengers', 'Market Share MLA', 'Average MLA Fare'
            ,'Market Share LPA', 'Average LPA Fare']

file_train[vars] = scaler.fit_transform(file_train[vars])

file_train.head()
# Out:
# <ipython-input-145-eada5671508d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_train[vars] = scaler.fit_transform(file_train[vars])
# C:\Users\anchhabra\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      Average Flight Fare  Distance  Average Weekly Passengers  \
# 278             0.242679  0.163006                   0.008031
# 218             0.342876  0.411561                   0.046940
# 909             0.166919  0.199615                   0.088760
# 718             0.518634  0.804624                   0.093632
# 111             0.235294  0.284778                   0.031929
#
#      Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# 278          0.472546          0.192965          0.242268          0.240531
# 218          0.621599          0.291734          0.114312          0.259617
# 909          0.520165          0.135651          0.367192          0.167062
# 718          0.225097          0.444654          0.159794          0.517812
# 111          0.377187          0.188005          0.391652          0.240383

# %%
file_train.describe()
# Out:
#        Average Flight Fare    Distance  Average Weekly Passengers  \
# count           699.000000  699.000000                 699.000000
# mean              0.326894    0.361787                   0.057101
# std               0.161864    0.254454                   0.090548
# min               0.000000    0.000000                   0.000000
# 25%               0.220153    0.161657                   0.008831
# 50%               0.320065    0.305202                   0.025472
# 75%               0.423655    0.527553                   0.067025
# max               1.000000    1.000000                   1.000000
#
#        Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# count        699.000000        699.000000        699.000000        699.000000
# mean           0.512096          0.268918          0.345911          0.280172
# std            0.238426          0.147502          0.275680          0.145255
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.345724          0.168426          0.124672          0.187837
# 50%            0.502308          0.255239          0.263695          0.264892
# 75%            0.677114          0.352176          0.539620          0.359582
# max            1.000000          1.000000          1.000000          1.000000

# %%
# # Apply scaler() to all the columns except the 'dummy' variables
# vars = ['Average Flight Fare', 'Distance', 'Average Weekly Passengers', 'Market Share MLA', 'Average MLA Fare'
#             ,'Market Share LPA', 'Average LPA Fare']

# file[vars] = scaler.fit_transform(file[vars])

# %%
# file.head()

# %% [markdown]
# ## Test Data transformation

# %%
file_test[vars] = scaler.transform(file_test[vars])
# Out:
# <ipython-input-149-c0db0864dd5d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_test[vars] = scaler.transform(file_test[vars])
# C:\Users\anchhabra\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
file_test.describe()
# Out:
#        Average Flight Fare    Distance  Average Weekly Passengers  \
# count           300.000000  300.000000                 300.000000
# mean              0.310367    0.348524                   0.053448
# std               0.147813    0.232065                   0.079845
# min               0.007043   -0.008092                   0.000049
# 25%               0.210109    0.175337                   0.007762
# 50%               0.291437    0.299229                   0.025583
# 75%               0.408928    0.455395                   0.067385
# max               0.679964    0.997303                   0.827958
#
#        Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# count        300.000000        300.000000        300.000000        300.000000
# mean           0.523535          0.253696          0.320042          0.262107
# std            0.228248          0.130018          0.268861          0.126275
# min            0.046890          0.005620          0.001112         -0.002697
# 25%            0.368896          0.165952          0.116333          0.186118
# 50%            0.507228          0.243180          0.220234          0.242472
# 75%            0.687986          0.335425          0.495730          0.329078
# max            1.000000          0.601852          1.000000          0.706212

# %%
X_train = file_train.drop('Average Flight Fare',axis=1)
y_train = file_train.pop('Average Flight Fare')

# %% [markdown]
# ### 4.2.3. Fitting Regression Model - Stats Model

# %%
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train)

# %%
X_train_lm.head()
# Out:
#      const  Distance  Average Weekly Passengers  Market Share MLA  \
# 278    1.0  0.163006                   0.008031          0.472546
# 218    1.0  0.411561                   0.046940          0.621599
# 909    1.0  0.199615                   0.088760          0.520165
# 718    1.0  0.804624                   0.093632          0.225097
# 111    1.0  0.284778                   0.031929          0.377187
#
#      Average MLA Fare  Market Share LPA  Average LPA Fare
# 278          0.192965          0.242268          0.240531
# 218          0.291734          0.114312          0.259617
# 909          0.135651          0.367192          0.167062
# 718          0.444654          0.159794          0.517812
# 111          0.188005          0.391652          0.240383

# %%
lr_1 = sm.OLS(y_train, X_train_lm).fit()

# %%
print(lr_1.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Average Flight Fare   R-squared:                       0.974
# Model:                             OLS   Adj. R-squared:                  0.974
# Method:                  Least Squares   F-statistic:                     4319.
# Date:                 Sat, 14 Aug 2021   Prob (F-statistic):               0.00
# Time:                         09:47:01   Log-Likelihood:                 1556.9
# No. Observations:                  699   AIC:                            -3100.
# Df Residuals:                      692   BIC:                            -3068.
# Df Model:                            6
# Covariance Type:             nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.0266      0.005      5.908      0.000       0.018       0.035
# Distance                      0.0188      0.006      3.327      0.001       0.008       0.030
# Average Weekly Passengers    -0.0234      0.011     -2.089      0.037      -0.045      -0.001
# Market Share MLA              0.0164      0.005      3.095      0.002       0.006       0.027
# Average MLA Fare              0.8606      0.015     58.712      0.000       0.832       0.889
# Market Share LPA             -0.0219      0.005     -4.710      0.000      -0.031      -0.013
# Average LPA Fare              0.2231      0.014     15.912      0.000       0.196       0.251
# ==============================================================================
# Omnibus:                       91.684   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              407.842
# Skew:                           0.506   Prob(JB):                     2.74e-89
# Kurtosis:                       6.603   Cond. No.                         25.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Given Model is able to explain 97% + data

# %% [markdown]
# ## Sklearn Way

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression() #call the function
lm
# Out:
# LinearRegression()

# %%
lm.fit(X_train,y_train) #fit the model

print(lm.intercept_) #see the intercept
print(lm.coef_) #see the betas
# Out:
# 0.026630690305396054
# [ 0.01882058 -0.02339433  0.01644456  0.8606073  -0.02189112  0.22310595]

# %%
y_pred = lm.predict(X_train)

# %%
from sklearn.metrics import r2_score
r2_score(y_train, y_pred)
# Out:
# 0.9739879552673862

# %% [markdown]
# ## Using VIF to cut down features

# %%
X_train.head()
# Out:
#      Distance  Average Weekly Passengers  Market Share MLA  Average MLA Fare  \
# 278  0.163006                   0.008031          0.472546          0.192965
# 218  0.411561                   0.046940          0.621599          0.291734
# 909  0.199615                   0.088760          0.520165          0.135651
# 718  0.804624                   0.093632          0.225097          0.444654
# 111  0.284778                   0.031929          0.377187          0.188005
#
#      Market Share LPA  Average LPA Fare
# 278          0.242268          0.240531
# 218          0.114312          0.259617
# 909          0.367192          0.167062
# 718          0.159794          0.517812
# 111          0.391652          0.240383

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

X = X_train

vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                     Features    VIF
# 3           Average MLA Fare  20.34
# 5           Average LPA Fare  19.63
# 2           Market Share MLA   5.09
# 0                   Distance   4.98
# 4           Market Share LPA   3.90
# 1  Average Weekly Passengers   1.35

# %% [markdown]
# Average MLA Fare has highest VIF, dropping it and checking results

# %%
X_new2 = X.drop('Average MLA Fare', axis=1)

# %%
X_new2.head()
# Out:
#      Distance  Average Weekly Passengers  Market Share MLA  Market Share LPA  \
# 278  0.163006                   0.008031          0.472546          0.242268
# 218  0.411561                   0.046940          0.621599          0.114312
# 909  0.199615                   0.088760          0.520165          0.367192
# 718  0.804624                   0.093632          0.225097          0.159794
# 111  0.284778                   0.031929          0.377187          0.391652
#
#      Average LPA Fare
# 278          0.240531
# 218          0.259617
# 909          0.167062
# 718          0.517812
# 111          0.240383

# %%
sns.heatmap(X_new2.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
Image("VIF_Image.png")

# %%
X_train_lm = sm.add_constant(X_new2)
lr_4 = sm.OLS(y_train, X_train_lm).fit()

# %%
print(lr_4.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Average Flight Fare   R-squared:                       0.844
# Model:                             OLS   Adj. R-squared:                  0.843
# Method:                  Least Squares   F-statistic:                     752.2
# Date:                 Sat, 14 Aug 2021   Prob (F-statistic):          3.97e-277
# Time:                         09:43:17   Log-Likelihood:                 931.80
# No. Observations:                  699   AIC:                            -1852.
# Df Residuals:                      693   BIC:                            -1824.
# Df Model:                            5
# Covariance Type:             nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.0534      0.011      4.873      0.000       0.032       0.075
# Distance                      0.0752      0.014      5.521      0.000       0.048       0.102
# Average Weekly Passengers     0.0291      0.027      1.067      0.286      -0.024       0.083
# Market Share MLA              0.1091      0.012      8.803      0.000       0.085       0.133
# Market Share LPA             -0.1651      0.010    -17.084      0.000      -0.184      -0.146
# Average LPA Fare              0.8775      0.021     42.207      0.000       0.837       0.918
# ==============================================================================
# Omnibus:                      301.511   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2121.841
# Skew:                           1.785   Prob(JB):                         0.00
# Kurtosis:                      10.753   Cond. No.                         14.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_new2
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                     Features   VIF
# 4           Average LPA Fare  6.54
# 0                   Distance  4.68
# 2           Market Share MLA  3.86
# 3           Market Share LPA  2.84
# 1  Average Weekly Passengers  1.33

# %% [markdown]
# VIF goes above 5, you can assume that the regression coefficients are poorly estimated due to multicollinearity.

# %%
# Market Share has a high p value and a High VIF
X_new2 = X.drop('Average LPA Fare', axis = 1)

# %%
X_new2.head()
# Out:
#      Distance  Average Weekly Passengers  Market Share MLA  Market Share LPA
# 278  0.163006                   0.008031          0.472546          0.242268
# 218  0.411561                   0.046940          0.621599          0.114312
# 909  0.199615                   0.088760          0.520165          0.367192
# 718  0.804624                   0.093632          0.225097          0.159794
# 111  0.284778                   0.031929          0.377187          0.391652

# %%
X_train_lm = sm.add_constant(X_new2)
lr_4 = sm.OLS(y_train, X_train_lm).fit()

# %%
print(lr_4.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Average Flight Fare   R-squared:                       0.444
# Model:                             OLS   Adj. R-squared:                  0.441
# Method:                  Least Squares   F-statistic:                     138.8
# Date:                 Sat, 14 Aug 2021   Prob (F-statistic):           4.04e-87
# Time:                         09:45:11   Log-Likelihood:                 486.99
# No. Observations:                  699   AIC:                            -964.0
# Df Residuals:                      694   BIC:                            -941.2
# Df Model:                            4
# Covariance Type:             nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.2048      0.020     10.471      0.000       0.166       0.243
# Distance                      0.3638      0.022     16.351      0.000       0.320       0.407
# Average Weekly Passengers    -0.0860      0.051     -1.678      0.094      -0.187       0.015
# Market Share MLA              0.1069      0.023      4.565      0.000       0.061       0.153
# Market Share LPA             -0.1714      0.018     -9.393      0.000      -0.207      -0.136
# ==============================================================================
# Omnibus:                       56.325   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.952
# Skew:                           0.747   Prob(JB):                     1.76e-15
# Kurtosis:                       3.320   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_new2
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                     Features   VIF
# 2           Market Share MLA  3.34
# 3           Market Share LPA  2.82
# 0                   Distance  1.64
# 1  Average Weekly Passengers  1.33

# %% [markdown]
# ##### Average MLA fare is the single most important feature.
# ##### Distance and Average Weekly Passengers are important to some extent

# %% [markdown]
# ### 4.2.4. Residual Analysis

# %%
X_train_lm.head()
# Out:
#      const  Distance  Average Weekly Passengers  Market Share MLA  \
# 278    1.0  0.163006                   0.008031          0.472546
# 218    1.0  0.411561                   0.046940          0.621599
# 909    1.0  0.199615                   0.088760          0.520165
# 718    1.0  0.804624                   0.093632          0.225097
# 111    1.0  0.284778                   0.031929          0.377187
#
#      Average MLA Fare  Market Share LPA  Average LPA Fare
# 278          0.192965          0.242268          0.240531
# 218          0.291734          0.114312          0.259617
# 909          0.135651          0.367192          0.167062
# 718          0.444654          0.159794          0.517812
# 111          0.188005          0.391652          0.240383

# %%
y_train_pred = lr_1.predict(X_train_lm)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# #### Error Terms are normally distributed - hence prediction can be made

# %% [markdown]
# ### 4.2.5. Making prediction using final model

# %%
# num_vars = ['Average Flight Fare', 'Distance','Average Weekly Passengers',
#                'Market Share MLA', 'Average MLA Fare', 'Market Share LPA', 'Average LPA Fare']

# file_test[num_vars] = scaler.transform(file_test[num_vars])

# %%
file_test.head()
# Out:
#      Average Flight Fare  Distance  Average Weekly Passengers  \
# 886             0.305181  0.351060                   0.009594
# 563             0.365031  0.924085                   0.033813
# 878             0.229905  0.271676                   0.065333
# 423             0.679964  0.509056                   0.039986
# 146             0.316102  0.405010                   0.000967
#
#      Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# 886          0.438533          0.217287          0.532848          0.283030
# 563          0.117468          0.261496          0.104609          0.323751
# 878          0.739189          0.176720          0.783000          0.230188
# 423          0.691448          0.565107          0.115626          0.638848
# 146          0.147473          0.247253          0.290681          0.322062

# %%
y_test = file_test.pop('Average Flight Fare')
X_test = file_test

# %%
# Adding constant variable to test dataframe
X_test_m4 = sm.add_constant(X_test)

# %%
# X_test_m4 = X_test_m4.drop(["Market Share MLA", "Market Share LPA", "Average LPA Fare"], axis = 1)

# %%
y_pred_test = lr_1.predict(X_test_m4)
y_pred_test.shape
# Out:
# (300,)

# %%
# Plotting y_test and y_pred to understand the spread
fig = plt.figure()
plt.scatter(y_test, y_pred_test)
fig.suptitle('y_test vs y_pred_test', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred_test', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred_test')

# %%
from sklearn import metrics
metrics.explained_variance_score(y_test, y_pred_m4)
# Out:
# 0.9739341979519447

# %% [markdown]
# ####  Model is able to explain 90% + of variance in test data  & 96% + variance in train data

# %%
residuals_test = y_test - y_pred_test
residuals_train = y_train - y_train_pred

# %%
print(sns.distplot(residuals_test))
print(sns.distplot(residuals_train))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# ResidualPlots on test data
plt.figure(figsize=(10,5))
p = sns.lineplot(y_pred_test,residuals_test,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
# plt.ylim(-2,5000000)
# plt.xlim(0,100000)
p = sns.lineplot([0,2600000],[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')

# %%
#make prediction
print(metrics.mean_absolute_error(y_test,y_pred_test))
print(metrics.mean_squared_error(y_test,y_pred_test))
print(metrics.mean_squared_log_error(y_test,y_pred_test))

from sklearn.metrics import r2_score
r2_score(y_test, y_pred_test)
# Out:
# 0.017820518779697096
# 0.0005676024859002528
# 0.00030458206525327584
# 0.9739341898816721

# %% [markdown]
# ## Autocorrelation

# %%
from statsmodels.stats.stattools import durbin_watson
#perform Durbin-Watson test
durbin_watson(lr_1.resid)
# Out:
# 2.126911141483334

# %% [markdown]
# * Values of 1.5 < d < 2.5 generally show that there is no autocorrelation in the data
# * A test statistic of 2 indicates no serial correlation
# * The closer the test statistics is to 0, the more evidence of positive serial correlation
# * The closer the test statistics is to 4, the more evidence of negative serial correlation

# %%
# autocorrelation
sm.graphics.tsa.plot_acf(lr_1.resid, lags=40)
plt.show()

# %% [markdown]
# ## Homoscadesticity

# %% [markdown]
# This assumes homoscedasticity, which is the same variance within our error terms. Heteroscedasticity, the violation of homoscedasticity, occurs when we don’t have an even variance across the error terms

# %% [markdown]
# **Why it can happen**: Our model may be giving too much weight to a subset of the data, particularly where the error variance was the largest

# %% [markdown]
# **How to detect it**: Plot the residuals and see if the variance appears to be uniform.
#
# **How to fix it**: Heteroscedasticity (can you tell I like the scedasticity words?) can be solved either by using weighted least squares regression instead of the standard OLS or transforming either the dependent or highly skewed variables. Performing a log transformation on the dependent variable is not a bad place to start

# %% [markdown]
# **What it will affect**: Significance tests for coefficients due to the standard errors being biased. Additionally, the confidence intervals will be either too wide or too narrow
#
# When residuals do not have constant variance (they exhibit heteroscedasticity), it is difficult to determine the true standard deviation of the forecast errors, usually resulting in confidence intervals that are too wide/narrow. For example, if the variance of the residuals is increasing over time, confidence intervals for out-of-sample predictions will be unrealistically narrow. Another effect of heteroscedasticity might also be putting too much weight to a subset of data when estimating coefficients — the subset in which the error variance was largest. To investigate if the residuals are homoscedastic, we can look at a plot of residuals (or standardized residuals) vs. predicted (fitted) values. What should alarm us is the case when the residuals grow either as a function of predicted value or time (in case of time series). We can also use two statistical tests: Breusch-Pagan and Goldfeld-Quandt. In both of them, the null hypothesis assumes homoscedasticity and a p-value below a certain level (like 0.05) indicates we should reject the null in favor of heteroscedasticity.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 6.0)

def homoscedasticity_test(model):
    '''
    Function for testing the homoscedasticity of residuals in a linear regression model.
    It plots residuals and standardized residuals vs. fitted values and runs Breusch-Pagan and Goldfeld-Quandt tests.
    
    Args:
    * model - fitted OLS model from statsmodels
    '''
    fitted_vals = model.predict()
    resids = model.resid
    resids_standardized = model.get_influence().resid_studentized_internal

    fig, ax = plt.subplots(1,2)

    sns.regplot(x = fitted_vals, y=resids, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Residuals vs Fitted', fontsize=16)
    ax[0].set(xlabel='Fitted Values', ylabel='Residuals')

    sns.regplot(x = fitted_vals, y=np.sqrt(np.abs(resids_standardized)), lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Scale-Location', fontsize=16)
    ax[1].set(xlabel='Fitted Values', ylabel='sqrt(abs(Residuals))')

    bp_test = pd.DataFrame(sms.het_breuschpagan(resids, model.model.exog), 
                           columns=['value'],
                           index=['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value'])

    gq_test = pd.DataFrame(sms.het_goldfeldquandt(resids, model.model.exog)[:-1],
                           columns=['value'],
                           index=['F statistic', 'p-value'])

    print('\n Breusch-Pagan test ----')
    print(bp_test)
    print('\n Goldfeld-Quandt test ----')
    print(gq_test)
    print('\n Residuals plots ----')

# %%
homoscedasticity_test(lr_1)
# Out:
#  Breusch-Pagan test ----
#                                       value
# Lagrange multiplier statistic  9.848439e+01
# p-value                        5.195962e-19
# f-value                        1.891463e+01
# f p-value                      1.880287e-20
#
#  Goldfeld-Quandt test ----
#                 value
# F statistic  0.871626
# p-value      0.897931
#
#  Residuals plots ----

# %% [markdown]
# * ***The results indicate that the assumption is not satisfied and we should reject the hypothesis of homoscedasticity.***
#
# * **Potential solutions:**
#     * log transformation of the dependent variable
#     * In case of time series, deflating a series if it concerns monetary value
#     * Using ARCH (auto-regressive conditional heteroscedasticity) models to model the error variance. An example might be stock market, where data can exhibit periods of increased or decreased volatility over time (volatility clustering, see this article for more information)

# %% [markdown]
# # 5. Other Models that can be applied

# %% [markdown]
# ##### 1. Polynomian Regression to capture non linearity in data
# ##### 2. Decision Tree with Regression at nodes (ensemble model)

# %% [markdown]
# # 6. Other ways of improving data:

# %% [markdown]
# ##### 1. Better independent variables can be derived. Some independent variables include:
#         a. Average MlA Fare / Distance b. Average LPA Fare / Distance c. Average MLA fare / Number of passengers d. Average
#             LPA fare / Number of passengers
# ##### 2. Completely new dependent variables can be introduced like:
#         b. Number of flights plying on each route
#
# ##### 3. PCA can identify better independent variable with minimum co-relation

# %% [markdown]
# # 7. Conclusion

# %% [markdown]
# ##### 1. As for Multivariate Analysis, Average MLA Fare is the most important independent variable.
# ##### 2. Distance and Average Weekly passenger count also effect Flight charges
# ##### 3. Multivariate analysis gives decent modl with more than 90% R2 on test data set
# ##### 4. Accuracy (read R2) can be improved further using features explained above (using alternated model or adding more variables)
# ##### 5. Transformations like log can improve model accuracy slightly but still effect of Average MLA stays most significant
#
# #### Understanding from EDA:
#
# ##### 1. Most of the flight fare lie between 100 to 300 with some outliers
# ##### 2. Average distance ranges between 500 to 2500
# ##### 3. Most of the time Average Weekly Passenger numer is less than 2000 but there are large number of outliers
# ##### 4. Average fare of both Market Leader and Low Price Airline range from 100 to 300 with some outliers
# ##### 5. Market Leader has 40 to 80 percent market share on most routes
# ##### 6. Lower Price airline has less than 40 percent market share on most of the routes
# ##### 7. Most flights have comparable median flight fare with some having very low values
# ##### 8. Flight fare of market leading airline and Low Price airline seem to fall in similar range
