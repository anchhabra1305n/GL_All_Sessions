# %%
#Proprietary content. ©Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
print('Numpy Version',np.__version__)
print('Pandas Version',pd.__version__)
print('Seaborn Version',sns.__version__)
print('Matplotlib Version',matplotlib.__version__)
# Out:
# Numpy Version 1.19.2
# Pandas Version 1.2.1
# Seaborn Version 0.11.1
# Matplotlib Version 3.3.2

# %%
sns.set()
sns.set_palette(palette='deep')
import folium
from folium.plugins import FastMarkerCluster

# %% [markdown]
# # Read the Data

# %%
# import os
# os.chdir('C:\\GL Class\\Solution Preparation\EDA')
listings= pd.read_csv('listings_summary.csv')
listings.head()
# Out:
#      id     scrape_id  last_scraped experiences_offered  host_id host_name  \
# 0  2015  2.018110e+13         43411                none     2217       Ian
# 1  2695  2.018110e+13         43411                none     2986   Michael
# 2  3176  2.018110e+13         43411                none     3718    Britta
# 3  3309  2.018110e+13         43411                none     4108      Jana
# 4  7071  2.018110e+13         43411                none    17391    Bright
#
#    host_since                         host_location host_response_time  \
# 0  18-08-2008  Key Biscayne, Florida, United States     within an hour
# 1  16-09-2008               Berlin, Berlin, Germany                NaN
# 2  19-10-2008  Coledale, New South Wales, Australia       within a day
# 3  07-11-2008               Berlin, Berlin, Germany                NaN
# 4  16-05-2009               Berlin, Berlin, Germany     within an hour
#
#    host_response_rate  ...  review_scores_value requires_license  \
# 0                0.96  ...                  9.0                t
# 1                 NaN  ...                 10.0                t
# 2                1.00  ...                  9.0                t
# 3                 NaN  ...                  9.0                t
# 4                1.00  ...                  9.0                t
#
#   jurisdiction_names  instant_bookable  is_business_travel_ready  \
# 0                NaN                 f                         f
# 1                NaN                 f                         f
# 2                NaN                 t                         f
# 3                NaN                 f                         f
# 4                NaN                 f                         f
#
#            cancellation_policy require_guest_profile_picture  \
# 0  strict_14_with_grace_period                             f
# 1                     flexible                             f
# 2  strict_14_with_grace_period                             f
# 3  strict_14_with_grace_period                             f
# 4                     moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              4
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              3.76
# 1              1.42
# 2              1.25
# 3              0.39
# 4              1.75
#
# [5 rows x 76 columns]

# %%
pd.options.display.max_columns = None

# %%
listings.head()
# Out:
#      id     scrape_id  last_scraped experiences_offered  host_id host_name  \
# 0  2015  2.018110e+13         43411                none     2217       Ian
# 1  2695  2.018110e+13         43411                none     2986   Michael
# 2  3176  2.018110e+13         43411                none     3718    Britta
# 3  3309  2.018110e+13         43411                none     4108      Jana
# 4  7071  2.018110e+13         43411                none    17391    Bright
#
#    host_since                         host_location host_response_time  \
# 0  18-08-2008  Key Biscayne, Florida, United States     within an hour
# 1  16-09-2008               Berlin, Berlin, Germany                NaN
# 2  19-10-2008  Coledale, New South Wales, Australia       within a day
# 3  07-11-2008               Berlin, Berlin, Germany                NaN
# 4  16-05-2009               Berlin, Berlin, Germany     within an hour
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                0.96                   NaN                 t
# 1                 NaN                   NaN                 f
# 2                1.00                   NaN                 f
# 3                 NaN                   NaN                 f
# 4                1.00                   NaN                 t
#
#   host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0              Mitte                  4.0                        4.0
# 1    Prenzlauer Berg                  1.0                        1.0
# 2    Prenzlauer Berg                  1.0                        1.0
# 3         Schöneberg                  1.0                        1.0
# 4    Prenzlauer Berg                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#   host_identity_verified                   street    neighbourhood  \
# 0                      t  Berlin, Berlin, Germany            Mitte
# 1                      t  Berlin, Berlin, Germany              NaN
# 2                      t  Berlin, Berlin, Germany  Prenzlauer Berg
# 3                      t  Berlin, Berlin, Germany       Schöneberg
# 4                      t  Berlin, Berlin, Germany  Prenzlauer Berg
#
#      neighbourhood_cleansed neighbourhood_group_cleansed    city   state  \
# 0           Brunnenstr. Süd                        Mitte  Berlin  Berlin
# 1  Prenzlauer Berg Nordwest                       Pankow  Berlin  Berlin
# 2   Prenzlauer Berg Südwest                       Pankow  Berlin  Berlin
# 3           Schöneberg-Nord       Tempelhof - Schöneberg  Berlin  Berlin
# 4            Helmholtzplatz                       Pankow  Berlin  Berlin
#
#   zipcode  market   smart_location country_code  country   latitude  \
# 0   10119  Berlin  Berlin, Germany           DE  Germany  52.534537
# 1   10437  Berlin  Berlin, Germany           DE  Germany  52.548513
# 2   10405  Berlin  Berlin, Germany           DE  Germany  52.534996
# 3   10777  Berlin  Berlin, Germany           DE  Germany  52.498855
# 4   10437  Berlin  Berlin, Germany           DE  Germany  52.543157
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0  13.402557                 f    Guesthouse  Entire home/apt             3
# 1  13.404553                 t     Apartment     Private room             2
# 2  13.417579                 t     Apartment  Entire home/apt             4
# 3  13.349065                 t     Apartment     Private room             2
# 4  13.415091                 t     Apartment     Private room             2
#
#    bathrooms  bedrooms  beds       bed_type  \
# 0        1.0       1.0   2.0       Real Bed
# 1        1.0       1.0   1.0       Real Bed
# 2        1.0       1.0   2.0       Real Bed
# 3        1.0       1.0   1.0  Pull-out Sofa
# 4        1.0       1.0   2.0       Real Bed
#
#                                            amenities  square_feet   price  \
# 0  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...          NaN  $60.00
# 1  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...          NaN  $17.00
# 2  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...        720.0  $90.00
# 3  {Internet,Wifi,"Pets allowed","Pets live on th...          0.0  $26.00
# 4  {Wifi,Heating,"Family/kid friendly",Essentials...          NaN  $42.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $200.00       $30.00                1
# 1          NaN           NaN            $0.00        $0.00                1
# 2      $520.00     $1,900.00          $200.00       $50.00                2
# 3      $175.00       $599.00          $250.00       $30.00                1
# 4          NaN           NaN            $0.00        $0.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0       $28.00               4            1125     3 months ago
# 1        $0.00               2              40      7 weeks ago
# 2       $20.00              62            1125       a week ago
# 3       $18.00               5             360      4 weeks ago
# 4       $24.00               2              10       3 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0               21               51
# 1                t                0                0                0
# 2                t                0                0                0
# 3                t                0                0               22
# 4                t               15               26               26
#
#    availability_365  calendar_last_scraped  number_of_reviews  first_review  \
# 0               141                  43411                118       42471.0
# 1                 0                  43411                  6       43285.0
# 2               220                  43411                143       39984.0
# 3               297                  43411                 25       41498.0
# 4                26                  43411                197       40043.0
#
#    last_review  review_scores_rating  review_scores_accuracy  \
# 0      43401.0                  93.0                    10.0
# 1      43374.0                 100.0                    10.0
# 2      42814.0                  92.0                     9.0
# 3      43328.0                  88.0                     9.0
# 4      43408.0                  96.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                       10.0                   10.0
# 2                        9.0                    9.0
# 3                        9.0                    9.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                 10.0
# 2                          9.0                    10.0                  9.0
# 3                         10.0                     9.0                  9.0
# 4                         10.0                    10.0                  9.0
#
#   requires_license  jurisdiction_names instant_bookable  \
# 0                t                 NaN                f
# 1                t                 NaN                f
# 2                t                 NaN                t
# 3                t                 NaN                f
# 4                t                 NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               4               3.76
# 1                               1               1.42
# 2                               1               1.25
# 3                               1               0.39
# 4                               1               1.75

# %%
## Checking the shape of the data: Number of columns and rows

listings.shape
# Out:
# (22552, 76)

# %%
## As the data set pertains to Berlin, some of the features have values for Berlin/Germany and hence such features will not show any
## variance from modeling perspective and hence the same should be dropped.. As an example let's look at the values in smart_location feature.
listings["smart_location"].value_counts()
# Out:
# Berlin, Germany                              22419
# ., Germany                                      12
# Berlin , Germany                                12
# Schöneberg, Germany                             11
# Mitte, Germany                                   8
#                                              ...
# Baseler Straße 91 A,12205 Berlin, Germany        1
# Berlin Neukölln, Germany                         1
# Berlin (Kreuzberg), Germany                      1
# Berlin (Wedding), Germany                        1
# Glienicke/Nordbahn, Germany                      1
# Name: smart_location, Length: 61, dtype: int64

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 76 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22552 non-null  int64
#  1   scrape_id                         22552 non-null  float64
#  2   last_scraped                      22552 non-null  int64
#  3   experiences_offered               22552 non-null  object
#  4   host_id                           22552 non-null  int64
#  5   host_name                         22526 non-null  object
#  6   host_since                        22526 non-null  object
#  7   host_location                     22436 non-null  object
#  8   host_response_time                9658 non-null   object
#  9   host_response_rate                9657 non-null   float64
#  10  host_acceptance_rate              0 non-null      float64
#  11  host_is_superhost                 22526 non-null  object
#  12  host_neighbourhood                17458 non-null  object
#  13  host_listings_count               22526 non-null  float64
#  14  host_total_listings_count         22526 non-null  float64
#  15  host_verifications                22552 non-null  object
#  16  host_has_profile_pic              22526 non-null  object
#  17  host_identity_verified            22526 non-null  object
#  18  street                            22552 non-null  object
#  19  neighbourhood                     21421 non-null  object
#  20  neighbourhood_cleansed            22552 non-null  object
#  21  neighbourhood_group_cleansed      22552 non-null  object
#  22  city                              22547 non-null  object
#  23  state                             22468 non-null  object
#  24  zipcode                           21896 non-null  object
#  25  market                            22489 non-null  object
#  26  smart_location                    22552 non-null  object
#  27  country_code                      22552 non-null  object
#  28  country                           22552 non-null  object
#  29  latitude                          22552 non-null  float64
#  30  longitude                         22552 non-null  float64
#  31  is_location_exact                 22552 non-null  object
#  32  property_type                     22552 non-null  object
#  33  room_type                         22552 non-null  object
#  34  accommodates                      22552 non-null  int64
#  35  bathrooms                         22520 non-null  float64
#  36  bedrooms                          22534 non-null  float64
#  37  beds                              22512 non-null  float64
#  38  bed_type                          22552 non-null  object
#  39  amenities                         22552 non-null  object
#  40  square_feet                       446 non-null    float64
#  41  price                             22552 non-null  object
#  42  weekly_price                      3681 non-null   object
#  43  monthly_price                     2659 non-null   object
#  44  security_deposit                  13191 non-null  object
#  45  cleaning_fee                      15406 non-null  object
#  46  guests_included                   22552 non-null  int64
#  47  extra_people                      22552 non-null  object
#  48  minimum_nights                    22552 non-null  int64
#  49  maximum_nights                    22552 non-null  int64
#  50  calendar_updated                  22552 non-null  object
#  51  has_availability                  22552 non-null  object
#  52  availability_30                   22552 non-null  int64
#  53  availability_60                   22552 non-null  int64
#  54  availability_90                   22552 non-null  int64
#  55  availability_365                  22552 non-null  int64
#  56  calendar_last_scraped             22552 non-null  int64
#  57  number_of_reviews                 22552 non-null  int64
#  58  first_review                      18638 non-null  float64
#  59  last_review                       18644 non-null  float64
#  60  review_scores_rating              18163 non-null  float64
#  61  review_scores_accuracy            18138 non-null  float64
#  62  review_scores_cleanliness         18141 non-null  float64
#  63  review_scores_checkin             18120 non-null  float64
#  64  review_scores_communication       18134 non-null  float64
#  65  review_scores_location            18121 non-null  float64
#  66  review_scores_value               18117 non-null  float64
#  67  requires_license                  22552 non-null  object
#  68  jurisdiction_names                0 non-null      float64
#  69  instant_bookable                  22552 non-null  object
#  70  is_business_travel_ready          22552 non-null  object
#  71  cancellation_policy               22552 non-null  object
#  72  require_guest_profile_picture     22552 non-null  object
#  73  require_guest_phone_verification  22552 non-null  object
#  74  calculated_host_listings_count    22552 non-null  int64
#  75  reviews_per_month                 18638 non-null  float64
# dtypes: float64(22), int64(14), object(40)
# memory usage: 13.1+ MB

# %%
### Examine missing values
listings_na = listings.isna().sum()
listings_na[listings_na.values > 0].sort_values(ascending=False) # Find out all variables that contain missing values
# Out:
# host_acceptance_rate           22552
# jurisdiction_names             22552
# square_feet                    22106
# monthly_price                  19893
# weekly_price                   18871
# host_response_rate             12895
# host_response_time             12894
# security_deposit                9361
# cleaning_fee                    7146
# host_neighbourhood              5094
# review_scores_value             4435
# review_scores_checkin           4432
# review_scores_location          4431
# review_scores_communication     4418
# review_scores_accuracy          4414
# review_scores_cleanliness       4411
# review_scores_rating            4389
# first_review                    3914
# reviews_per_month               3914
# last_review                     3908
# neighbourhood                   1131
# zipcode                          656
# host_location                    116
# state                             84
# market                            63
# beds                              40
# bathrooms                         32
# host_name                         26
# host_since                        26
# host_identity_verified            26
# host_has_profile_pic              26
# host_total_listings_count         26
# host_listings_count               26
# host_is_superhost                 26
# bedrooms                          18
# city                               5
# dtype: int64

# %% [markdown]
# jurisdiction_names             22552
# host_acceptance_rate           22552
# square_feet                    22106
# monthly_price                  19893
# weekly_price                   18871
# host_response_rate             12895
# host_response_time             12894
# security_deposit                9361
#
# All these features have high percentage of missing values and hence these features would be dropped from analysis. We are dropping them from our dataset to make sure that other valid observations do not get eliminated when we remove or impute the 'na' values.

# %%
listings.drop(['jurisdiction_names', 'host_acceptance_rate','square_feet','monthly_price','weekly_price' ,'host_response_rate','host_response_time' ,'security_deposit'],axis='columns', inplace=True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 68 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22552 non-null  int64
#  1   scrape_id                         22552 non-null  float64
#  2   last_scraped                      22552 non-null  int64
#  3   experiences_offered               22552 non-null  object
#  4   host_id                           22552 non-null  int64
#  5   host_name                         22526 non-null  object
#  6   host_since                        22526 non-null  object
#  7   host_location                     22436 non-null  object
#  8   host_is_superhost                 22526 non-null  object
#  9   host_neighbourhood                17458 non-null  object
#  10  host_listings_count               22526 non-null  float64
#  11  host_total_listings_count         22526 non-null  float64
#  12  host_verifications                22552 non-null  object
#  13  host_has_profile_pic              22526 non-null  object
#  14  host_identity_verified            22526 non-null  object
#  15  street                            22552 non-null  object
#  16  neighbourhood                     21421 non-null  object
#  17  neighbourhood_cleansed            22552 non-null  object
#  18  neighbourhood_group_cleansed      22552 non-null  object
#  19  city                              22547 non-null  object
#  20  state                             22468 non-null  object
#  21  zipcode                           21896 non-null  object
#  22  market                            22489 non-null  object
#  23  smart_location                    22552 non-null  object
#  24  country_code                      22552 non-null  object
#  25  country                           22552 non-null  object
#  26  latitude                          22552 non-null  float64
#  27  longitude                         22552 non-null  float64
#  28  is_location_exact                 22552 non-null  object
#  29  property_type                     22552 non-null  object
#  30  room_type                         22552 non-null  object
#  31  accommodates                      22552 non-null  int64
#  32  bathrooms                         22520 non-null  float64
#  33  bedrooms                          22534 non-null  float64
#  34  beds                              22512 non-null  float64
#  35  bed_type                          22552 non-null  object
#  36  amenities                         22552 non-null  object
#  37  price                             22552 non-null  object
#  38  cleaning_fee                      15406 non-null  object
#  39  guests_included                   22552 non-null  int64
#  40  extra_people                      22552 non-null  object
#  41  minimum_nights                    22552 non-null  int64
#  42  maximum_nights                    22552 non-null  int64
#  43  calendar_updated                  22552 non-null  object
#  44  has_availability                  22552 non-null  object
#  45  availability_30                   22552 non-null  int64
#  46  availability_60                   22552 non-null  int64
#  47  availability_90                   22552 non-null  int64
#  48  availability_365                  22552 non-null  int64
#  49  calendar_last_scraped             22552 non-null  int64
#  50  number_of_reviews                 22552 non-null  int64
#  51  first_review                      18638 non-null  float64
#  52  last_review                       18644 non-null  float64
#  53  review_scores_rating              18163 non-null  float64
#  54  review_scores_accuracy            18138 non-null  float64
#  55  review_scores_cleanliness         18141 non-null  float64
#  56  review_scores_checkin             18120 non-null  float64
#  57  review_scores_communication       18134 non-null  float64
#  58  review_scores_location            18121 non-null  float64
#  59  review_scores_value               18117 non-null  float64
#  60  requires_license                  22552 non-null  object
#  61  instant_bookable                  22552 non-null  object
#  62  is_business_travel_ready          22552 non-null  object
#  63  cancellation_policy               22552 non-null  object
#  64  require_guest_profile_picture     22552 non-null  object
#  65  require_guest_phone_verification  22552 non-null  object
#  66  calculated_host_listings_count    22552 non-null  int64
#  67  reviews_per_month                 18638 non-null  float64
# dtypes: float64(18), int64(14), object(36)
# memory usage: 11.7+ MB

# %%
### Let's examine the target column which is price

listings.describe(include="all")["price"]
# Out:
# count      22552
# unique       295
# top       $30.00
# freq        1387
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
# Name: price, dtype: object

# %%
listings.price.unique()
# Out:
# array(['$60.00', '$17.00', '$90.00', '$26.00', '$42.00', '$180.00',
#        '$70.00', '$120.00', '$45.00', '$49.00', '$129.00', '$98.00',
#        '$160.00', '$65.00', '$197.00', '$130.00', '$100.00', '$44.00',
#        '$62.00', '$55.00', '$40.00', '$25.00', '$52.00', '$39.00',
#        '$80.00', '$50.00', '$43.00', '$36.00', '$119.00', '$56.00',
#        '$48.00', '$88.00', '$200.00', '$37.00', '$102.00', '$29.00',
#        '$84.00', '$69.00', '$185.00', '$155.00', '$66.00', '$53.00',
#        '$92.00', '$75.00', '$114.00', '$506.00', '$82.00', '$68.00',
#        '$125.00', '$89.00', '$59.00', '$96.00', '$31.00', '$81.00',
#        '$161.00', '$30.00', '$23.00', '$35.00', '$76.00', '$46.00',
#        '$296.00', '$244.00', '$20.00', '$170.00', '$64.00', '$375.00',
#        '$32.00', '$86.00', '$79.00', '$38.00', '$74.00', '$195.00',
#        '$150.00', '$165.00', '$51.00', '$110.00', '$95.00', '$28.00',
#        '$85.00', '$58.00', '$63.00', '$175.00', '$19.00', '$91.00',
#        '$93.00', '$72.00', '$33.00', '$99.00', '$148.00', '$9.00',
#        '$61.00', '$34.00', '$54.00', '$235.00', '$77.00', '$149.00',
#        '$87.00', '$27.00', '$78.00', '$67.00', '$22.00', '$109.00',
#        '$83.00', '$209.00', '$47.00', '$189.00', '$15.00', '$73.00',
#        '$115.00', '$21.00', '$140.00', '$24.00', '$208.00', '$16.00',
#        '$107.00', '$190.00', '$455.00', '$2,228.00', '$106.00', '$139.00',
#        '$105.00', '$111.00', '$146.00', '$650.00', '$57.00', '$131.00',
#        '$145.00', '$329.00', '$135.00', '$108.00', '$350.00', '$18.00',
#        '$97.00', '$41.00', '$199.00', '$104.00', '$117.00', '$280.00',
#        '$158.00', '$137.00', '$580.00', '$124.00', '$250.00', '$193.00',
#        '$210.00', '$71.00', '$300.00', '$169.00', '$94.00', '$229.00',
#        '$390.00', '$147.00', '$8.00', '$12.00', '$153.00', '$159.00',
#        '$220.00', '$121.00', '$2,500.00', '$113.00', '$215.00', '$142.00',
#        '$123.00', '$128.00', '$400.00', '$450.00', '$258.00', '$144.00',
#        '$320.00', '$299.00', '$240.00', '$263.00', '$154.00', '$245.00',
#        '$525.00', '$118.00', '$380.00', '$156.00', '$101.00', '$500.00',
#        '$550.00', '$10.00', '$116.00', '$191.00', '$138.00', '$2,225.00',
#        '$800.00', '$399.00', '$219.00', '$600.00', '$112.00', '$13.00',
#        '$14.00', '$225.00', '$4,240.00', '$290.00', '$11.00', '$270.00',
#        '$275.00', '$255.00', '$595.00', '$177.00', '$285.00', '$187.00',
#        '$134.00', '$302.00', '$359.00', '$349.00', '$360.00', '$9,000.00',
#        '$304.00', '$260.00', '$179.00', '$103.00', '$899.00', '$1,900.00',
#        '$132.00', '$133.00', '$249.00', '$237.00', '$510.00', '$178.00',
#        '$444.00', '$421.00', '$330.00', '$222.00', '$460.00', '$259.00',
#        '$198.00', '$5,000.00', '$262.00', '$241.00', '$252.00', '$333.00',
#        '$203.00', '$172.00', '$319.00', '$227.00', '$279.00', '$265.00',
#        '$1,050.00', '$1,250.00', '$885.00', '$214.00', '$151.00',
#        '$196.00', '$499.00', '$157.00', '$1,000.00', '$269.00', '$0.00',
#        '$239.00', '$1,875.00', '$257.00', '$126.00', '$228.00', '$182.00',
#        '$297.00', '$599.00', '$8,000.00', '$230.00', '$288.00', '$999.00',
#        '$1.00', '$183.00', '$405.00', '$234.00', '$505.00', '$268.00',
#        '$188.00', '$224.00', '$332.00', '$357.00', '$379.00', '$439.00',
#        '$549.00', '$475.00', '$168.00', '$418.00', '$880.00', '$6,000.00',
#        '$340.00', '$3,000.00', '$181.00', '$166.00', '$174.00', '$480.00',
#        '$666.00', '$888.00', '$8,600.00', '$345.00', '$900.00', '$122.00',
#        '$136.00', '$1,500.00'], dtype=object)

# %% [markdown]
# As "price" is of type object rather than int/float. Looks like that there are some special characters which are making it as object. Therefore, we need to convert this column into numeric value.

# %%
listings["price"] = listings["price"].apply(lambda x: x.replace("$", "")) # Remove dollar sign
listings["price"] = listings["price"].apply(lambda x: x.replace(",", "")) # Remove thousand separator
listings["price"] = listings["price"].astype("float") # Cast the column into type float
listings.describe()["price"]
# Out:
# count    22552.000000
# mean        67.143668
# std        220.266210
# min          0.000000
# 25%         30.000000
# 50%         45.000000
# 75%         70.000000
# max       9000.000000
# Name: price, dtype: float64

# %% [markdown]
# Check the difference between 75% and Max value - looks like there are outliers/extreme values in the price variable. However as we are not sure if these are real outliers, we will not treat them right now.

# %%
listings["price"].value_counts().sort_index()
# Out:
# 0.0        8
# 1.0        1
# 8.0        4
# 9.0       22
# 10.0      26
#           ..
# 5000.0     2
# 6000.0    20
# 8000.0     1
# 8600.0     1
# 9000.0     1
# Name: price, Length: 295, dtype: int64

# %%
#Let's look at the distribution of price at different percentiles
print("0.5% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 0.5)))
print("  1% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 1)))
print("  5% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 5)))
print(" 10% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 10)))
print(" 90% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 90)))
print(" 95% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 95)))
print(" 99% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 99)))
print("99.5% properties have a price lower than {0: .2f}".format(np.percentile(listings["price"], 99.5)))
# Out:
# 0.5% properties have a price lower than  13.00
#   1% properties have a price lower than  15.00
#   5% properties have a price lower than  20.00
#  10% properties have a price lower than  24.00
#  90% properties have a price lower than  100.00
#  95% properties have a price lower than  140.00
#  99% properties have a price lower than  270.00
# 99.5% properties have a price lower than  400.00

# %%
## We are interested in building a model to correctly predict the listing price which are greater than 0 and less
## than 270

listings = listings[(listings.price > 1 ) & (listings.price < 270 )]

# %%
## Let's create a range variable to understand how many records we have in different slabs

price_range = pd.cut(listings["price"], 
                     bins=[0, 20, 40, 60, 80, 100, 120, 140, listings["price"].max()], 
                     labels=["0-20", "20-40", "40-60", "60-80", "80-100", "100-120", "120-140", "140+"])
listings["price_range"] = price_range 
listings["price_range"].value_counts().sort_index().plot(kind="bar")
plt.title("Number of Listings in each Price Range")
plt.show()

# %% [markdown]
# We can also consider 'Price' as a Multiclass classifier and predict the probability of a class , instead of using price as a numeric variable. Sometimes the business is interested in predicting/estimating the price range and not an exact price.
# However as we are working on regression model, this variable would be dropped

# %%
sns.histplot(listings['price'],bins=20);

# %%
sns.histplot(np.log(listings["price"]),bins=20);

# %% [markdown]
# Log transformation of the price variable looks to be slightly more symmetrically distributed. We can use a log of the price variable as our target variable in the regression model, to check if performance is better than the price feature used without any transformation

# %%
## This is a custom column that we created to visualize the Price variable in discrete format.

listings.drop(['price_range'], axis='columns', inplace=True)

# %%
## Let's look at one more variable related to price- cleaning fee

# replace missing values with zero and convert cleaning_fee column into numeric value
listings.cleaning_fee.fillna('$0.00', inplace=True)
listings.cleaning_fee = listings.cleaning_fee.str.replace('$', '').str.replace(',', '').astype(float).astype(int)
listings.cleaning_fee.isna().sum()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """
# 0

# %%
## is there are correlation between price and cleaning_fee
np.corrcoef(listings.cleaning_fee,listings.price)## Correlation is not high
# Out:
# array([[1.        , 0.40280616],
#        [0.40280616, 1.        ]])

# %%
## Although the correlation is not too high, however if we know the Price, we can calculate the cleaning_fee
## Objective is to find out which all parameters are significant to define the price
## So we will drop cleaning_fee and use price as a dependent variable.
## Keeping cleaning_fee as an independent feature would mean that this might turn out to be most 
## significant variable in predicting the value of price.

# %%
### Is demand dependent on if a host is a superhost

# check super host column for NaN's
listings.host_is_superhost.isna().sum()
# Out:
# 25

# %%
listings['host_is_superhost'].value_counts(1)
# Out:
# f    0.867384
# t    0.132616
# Name: host_is_superhost, dtype: float64

# %%
# replace NaN's with value 'false' for not being a superhost
listings.host_is_superhost.fillna(value='f', inplace=True)
listings.host_is_superhost.isna().sum()
# Out:
# 0

# %%
listings['host_is_superhost'].value_counts(1)
# Out:
# f    0.867533
# t    0.132467
# Name: host_is_superhost, dtype: float64

# %%
super_host    = listings.host_is_superhost.value_counts()['t']
no_super_host = listings.host_is_superhost.value_counts()['f']
names = ['Super Hosts','Standard Hosts']
size  = [super_host, no_super_host]
# create a pie chart
plt.pie(size, labels=names, colors=['darkorange','silver'], 
        autopct='%.2f%%', pctdistance=1.28,
        wedgeprops={'linewidth':7, 'edgecolor':'white'})

# create circle for the center of the plot to make the pie look like a donut
my_circle = plt.Circle((0,0), 0.6, color='white')

# plot the donut chart
fig = plt.gcf()
fig.set_size_inches(7,7)
fig.gca().add_artist(my_circle)
plt.show()

# %%
## Let's check if being a superhost has any price impact

plt.figure(figsize=(20,5))

chart=sns.boxplot(x="host_is_superhost", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=18)
plt.title('Superhost price distribution')
chart;

# %% [markdown]
# Judging from the above boxplot, being a superhost has no visible impact on the price. We can definitely try out appropriate Hypothesis Tests to confirm this.

# %%
## Let's study Latitude and Longitue features 

lat = listings['latitude'].tolist()
lon = listings['longitude'].tolist()
locations = list(zip(lat, lon))

# 52.5200° N, 13.4050° E is the latitude and longitude of berlin

map1 = folium.Map(location=[52.5200, 13.4050], zoom_start=12)
FastMarkerCluster(locations).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To better evaluate the location of each listing, we would like to calcuate the distance between each listing and one of the Top5 locations in Berlin. Here we define the Top5 locations as:
#
# Berlin main train station (hbf)
# Berlin Tegel Airport (txl)
# Brandenburg Tor (btor)
# Museum Island (museum)
# Reichstag (reichstag)

# %%
from math import sin, cos, sqrt, atan2, radians
def distance(lat1, lat2, lon1, lon2):
    R = 6373.0 ## Approx radius of earth in KM
    rlat1 = radians(lat1)
    rlat2 = radians(lat2)
    rlon1 = radians(lon1)
    rlon2 = radians(lon2)
    rdlon = rlon2 - rlon1
    rdlat = rlat2 - rlat1
    a = sin(rdlat / 2)**2 + cos(rlat1) * cos(rlat2) * sin(rdlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    return distance

# %%
# Top locations in Berlin
toploc = {"hbf": [52.525293, 13.369359], 
          "txl": [52.558794, 13.288437], 
          "btor": [52.516497, 13.377683], 
          "museum": [52.517693, 13.402141], 
          "reichstag": [52.518770, 13.376166]}
toploc = pd.DataFrame.from_dict(toploc)
toploc_trans = toploc.transpose()
toploc_trans.columns = ["latitude", "longitude"]

# Construct distance columns
dist = []
for col in toploc.columns:
    listings["dist_"+col] = listings.apply(lambda x: distance(x.latitude, toploc[col][0], x.longitude, toploc[col][1]), axis=1)
    dist.append("dist_"+col)

# %%
listings.info() ## 5 new variables pertaining to distance are created
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22315 entries, 0 to 22551
# Data columns (total 73 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22315 non-null  int64
#  1   scrape_id                         22315 non-null  float64
#  2   last_scraped                      22315 non-null  int64
#  3   experiences_offered               22315 non-null  object
#  4   host_id                           22315 non-null  int64
#  5   host_name                         22290 non-null  object
#  6   host_since                        22290 non-null  object
#  7   host_location                     22201 non-null  object
#  8   host_is_superhost                 22315 non-null  object
#  9   host_neighbourhood                17280 non-null  object
#  10  host_listings_count               22290 non-null  float64
#  11  host_total_listings_count         22290 non-null  float64
#  12  host_verifications                22315 non-null  object
#  13  host_has_profile_pic              22290 non-null  object
#  14  host_identity_verified            22290 non-null  object
#  15  street                            22315 non-null  object
#  16  neighbourhood                     21195 non-null  object
#  17  neighbourhood_cleansed            22315 non-null  object
#  18  neighbourhood_group_cleansed      22315 non-null  object
#  19  city                              22310 non-null  object
#  20  state                             22237 non-null  object
#  21  zipcode                           21664 non-null  object
#  22  market                            22253 non-null  object
#  23  smart_location                    22315 non-null  object
#  24  country_code                      22315 non-null  object
#  25  country                           22315 non-null  object
#  26  latitude                          22315 non-null  float64
#  27  longitude                         22315 non-null  float64
#  28  is_location_exact                 22315 non-null  object
#  29  property_type                     22315 non-null  object
#  30  room_type                         22315 non-null  object
#  31  accommodates                      22315 non-null  int64
#  32  bathrooms                         22283 non-null  float64
#  33  bedrooms                          22297 non-null  float64
#  34  beds                              22279 non-null  float64
#  35  bed_type                          22315 non-null  object
#  36  amenities                         22315 non-null  object
#  37  price                             22315 non-null  float64
#  38  cleaning_fee                      22315 non-null  int32
#  39  guests_included                   22315 non-null  int64
#  40  extra_people                      22315 non-null  object
#  41  minimum_nights                    22315 non-null  int64
#  42  maximum_nights                    22315 non-null  int64
#  43  calendar_updated                  22315 non-null  object
#  44  has_availability                  22315 non-null  object
#  45  availability_30                   22315 non-null  int64
#  46  availability_60                   22315 non-null  int64
#  47  availability_90                   22315 non-null  int64
#  48  availability_365                  22315 non-null  int64
#  49  calendar_last_scraped             22315 non-null  int64
#  50  number_of_reviews                 22315 non-null  int64
#  51  first_review                      18483 non-null  float64
#  52  last_review                       18489 non-null  float64
#  53  review_scores_rating              18014 non-null  float64
#  54  review_scores_accuracy            17989 non-null  float64
#  55  review_scores_cleanliness         17992 non-null  float64
#  56  review_scores_checkin             17971 non-null  float64
#  57  review_scores_communication       17985 non-null  float64
#  58  review_scores_location            17972 non-null  float64
#  59  review_scores_value               17968 non-null  float64
#  60  requires_license                  22315 non-null  object
#  61  instant_bookable                  22315 non-null  object
#  62  is_business_travel_ready          22315 non-null  object
#  63  cancellation_policy               22315 non-null  object
#  64  require_guest_profile_picture     22315 non-null  object
#  65  require_guest_phone_verification  22315 non-null  object
#  66  calculated_host_listings_count    22315 non-null  int64
#  67  reviews_per_month                 18483 non-null  float64
#  68  dist_hbf                          22315 non-null  float64
#  69  dist_txl                          22315 non-null  float64
#  70  dist_btor                         22315 non-null  float64
#  71  dist_museum                       22315 non-null  float64
#  72  dist_reichstag                    22315 non-null  float64
# dtypes: float64(24), int32(1), int64(14), object(34)
# memory usage: 13.0+ MB

# %%
## This dictionary contains only the names of the new distance related columns.

dist
# Out:
# ['dist_hbf', 'dist_txl', 'dist_btor', 'dist_museum', 'dist_reichstag']

# %%
from scipy import stats
for distance in dist:
    sns.scatterplot(x=distance, y="price", data=listings, alpha=0.3)
    plt.title("Correlation between price and "+distance)
    plt.show()

# %%
## As similar scatter plot was observed for all distance variables, let's take an average and create a new variable

listings['dist_average'] = listings[['dist_hbf', 'dist_txl', 'dist_btor', 'dist_museum', 'dist_reichstag']].mean(axis=1)

# %%
listings[['dist_hbf', 'dist_txl', 'dist_btor', 'dist_museum', 'dist_reichstag','dist_average']].head()
# Out:
#    dist_hbf  dist_txl  dist_btor  dist_museum  dist_reichstag  dist_average
# 0  2.470531  8.177076   2.619164     1.873802        2.503054      3.528725
# 1  3.512827  7.935716   3.998364     3.431962        3.825405      4.540855
# 2  3.436703  9.127423   3.394579     2.189884        3.333330      4.296384
# 3  3.245779  7.828150   2.757640     4.159571        2.876309      4.173490
# 4  3.677298  8.740897   3.898852     2.964838        3.780919      4.612561

# %%
sns.scatterplot(x='dist_average', y="price", data=listings, alpha=0.3);

# %%
sns.heatmap(listings[['dist_hbf','dist_txl','dist_btor','dist_museum','dist_reichstag','dist_average','price']].corr(),
            annot=True,mask=np.triu(listings[['dist_hbf','dist_txl','dist_btor','dist_museum','dist_reichstag','dist_average','price']].corr(),+1));

# %%
## We could also create a new variable as with a value as "good distance" and "bad distance" wherein distance value 
## from a location to these 5 key centres is lower then it is good distance ..

# %%
## Let's see how to deal with a feature which has text values

# %%
listings['amenities'].unique()
# Out:
# array(['{TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Family/kid friendly","Smoke detector",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Private living room",Bathtub,"Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Stove,"Luggage dropoff allowed","Long term stays allowed"}',
#        '{Wifi,Kitchen,Elevator,Heating,Washer,Essentials,Shampoo,"Hair dryer","Laptop friendly workspace","Private living room"}',
#        '{Internet,Wifi,Kitchen,"Buzzer/wireless intercom",Heating,"Family/kid friendly",Washer,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace"}',
#        ...,
#        '{Wifi,Kitchen,Heating,Washer,"Fire extinguisher",Essentials,Iron,"Hot water"}',
#        '{Wifi,"Paid parking off premises",Doorman,Elevator,Heating,"Family/kid friendly","Smoke detector","Safety card","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in","Building staff","Hot water"}',
#        '{Wifi,"Air conditioning",Kitchen,Breakfast,Heating,Washer,"Safety card",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer","Laptop friendly workspace"}'],
#       dtype=object)

# %%
## Let's identify 10 most frequently occuring amenities in the dataset
from collections import Counter
amenities = Counter()
listings['amenities'].str.strip('{}')\
               .str.replace('"', '')\
               .str.lstrip('\"')\
               .str.rstrip('\"')\
               .str.split(',')\
               .apply(amenities.update)

amenities.most_common(10)
# Out:
# [('Wifi', 21295),
#  ('Kitchen', 21135),
#  ('Heating', 20993),
#  ('Essentials', 20116),
#  ('Washer', 18330),
#  ('Hair dryer', 14708),
#  ('Laptop friendly workspace', 14296),
#  ('Hangers', 13728),
#  ('Iron', 11042),
#  ('Shampoo', 10500)]

# %%
## Feature Engineering - Creating a few columns with some amenities that we are looking at.

listings['Laptop_friendly_workspace'] = listings['amenities'].str.contains('Laptop friendly workspace')
listings['TV'] = listings['amenities'].str.contains('TV')
listings['Hot water']=listings['amenities'].str.contains('Hot water')
listings['Family_friendly'] = listings['amenities'].str.contains('Family/kid friendly')
listings['Hair_dryer'] = listings['amenities'].str.contains('Hair_dryer')
listings['Smoking_allowed'] = listings['amenities'].str.contains('Smoking allowed')

# %%
### Let's look at the feature list now
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22315 entries, 0 to 22551
# Data columns (total 80 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22315 non-null  int64
#  1   scrape_id                         22315 non-null  float64
#  2   last_scraped                      22315 non-null  int64
#  3   experiences_offered               22315 non-null  object
#  4   host_id                           22315 non-null  int64
#  5   host_name                         22290 non-null  object
#  6   host_since                        22290 non-null  object
#  7   host_location                     22201 non-null  object
#  8   host_is_superhost                 22315 non-null  object
#  9   host_neighbourhood                17280 non-null  object
#  10  host_listings_count               22290 non-null  float64
#  11  host_total_listings_count         22290 non-null  float64
#  12  host_verifications                22315 non-null  object
#  13  host_has_profile_pic              22290 non-null  object
#  14  host_identity_verified            22290 non-null  object
#  15  street                            22315 non-null  object
#  16  neighbourhood                     21195 non-null  object
#  17  neighbourhood_cleansed            22315 non-null  object
#  18  neighbourhood_group_cleansed      22315 non-null  object
#  19  city                              22310 non-null  object
#  20  state                             22237 non-null  object
#  21  zipcode                           21664 non-null  object
#  22  market                            22253 non-null  object
#  23  smart_location                    22315 non-null  object
#  24  country_code                      22315 non-null  object
#  25  country                           22315 non-null  object
#  26  latitude                          22315 non-null  float64
#  27  longitude                         22315 non-null  float64
#  28  is_location_exact                 22315 non-null  object
#  29  property_type                     22315 non-null  object
#  30  room_type                         22315 non-null  object
#  31  accommodates                      22315 non-null  int64
#  32  bathrooms                         22283 non-null  float64
#  33  bedrooms                          22297 non-null  float64
#  34  beds                              22279 non-null  float64
#  35  bed_type                          22315 non-null  object
#  36  amenities                         22315 non-null  object
#  37  price                             22315 non-null  float64
#  38  cleaning_fee                      22315 non-null  int32
#  39  guests_included                   22315 non-null  int64
#  40  extra_people                      22315 non-null  object
#  41  minimum_nights                    22315 non-null  int64
#  42  maximum_nights                    22315 non-null  int64
#  43  calendar_updated                  22315 non-null  object
#  44  has_availability                  22315 non-null  object
#  45  availability_30                   22315 non-null  int64
#  46  availability_60                   22315 non-null  int64
#  47  availability_90                   22315 non-null  int64
#  48  availability_365                  22315 non-null  int64
#  49  calendar_last_scraped             22315 non-null  int64
#  50  number_of_reviews                 22315 non-null  int64
#  51  first_review                      18483 non-null  float64
#  52  last_review                       18489 non-null  float64
#  53  review_scores_rating              18014 non-null  float64
#  54  review_scores_accuracy            17989 non-null  float64
#  55  review_scores_cleanliness         17992 non-null  float64
#  56  review_scores_checkin             17971 non-null  float64
#  57  review_scores_communication       17985 non-null  float64
#  58  review_scores_location            17972 non-null  float64
#  59  review_scores_value               17968 non-null  float64
#  60  requires_license                  22315 non-null  object
#  61  instant_bookable                  22315 non-null  object
#  62  is_business_travel_ready          22315 non-null  object
#  63  cancellation_policy               22315 non-null  object
#  64  require_guest_profile_picture     22315 non-null  object
#  65  require_guest_phone_verification  22315 non-null  object
#  66  calculated_host_listings_count    22315 non-null  int64
#  67  reviews_per_month                 18483 non-null  float64
#  68  dist_hbf                          22315 non-null  float64
#  69  dist_txl                          22315 non-null  float64
#  70  dist_btor                         22315 non-null  float64
#  71  dist_museum                       22315 non-null  float64
#  72  dist_reichstag                    22315 non-null  float64
#  73  dist_average                      22315 non-null  float64
#  74  Laptop_friendly_workspace         22315 non-null  bool
#  75  TV                                22315 non-null  bool
#  76  Hot water                         22315 non-null  bool
#  77  Family_friendly                   22315 non-null  bool
#  78  Hair_dryer                        22315 non-null  bool
#  79  Smoking_allowed                   22315 non-null  bool
# dtypes: bool(6), float64(25), int32(1), int64(14), object(34)
# memory usage: 13.3+ MB

# %%
freq = listings['neighbourhood_group_cleansed'].value_counts().sort_values(ascending=True)
freq.plot.barh(figsize=(10, 8), width=1)
plt.title("Number of Listings by Neighbourhood Group")
plt.xlabel('Number of Listings')
plt.show()

# %%
plt.figure(figsize=(20,5))

chart=sns.boxplot(x="neighbourhood_group_cleansed", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=18)
plt.title('Neighbourhood price distribution')
chart;

# %% [markdown]
# Price does vary based on the neighbourhood group, as expected. This conclusion can only be drawn through the graphical plots. For further analysis, appropriate statistical tests can be done.
#
# Let's analyse the impact on price using a combination of neighbourhood group along with other variables.

# %%
## Let us see the number of bedrooms of each property
print(listings['bedrooms'].value_counts(),'\n')


## How is the distribution of bedrooms with price.. Ideally if number of bedrooms are high, price would be high.
sns.boxplot(x="bedrooms", y="price", data=listings,palette="summer");
# Out:
# 1.0    17087
# 2.0     2926
# 0.0     1471
# 3.0      666
# 4.0      120
# 5.0       18
# 6.0        5
# 8.0        2
# 7.0        1
# 9.0        1
# Name: bedrooms, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.heatmap(listings.groupby(['neighbourhood_group_cleansed', 'bedrooms']).price.median().unstack(), 
            cmap='Reds', annot=True, fmt=".0f")

plt.xlabel('\nBedrooms', fontsize=12)
plt.ylabel('Neighbourhood Group\n', fontsize=12)
plt.title('\nHeatmap: Median Prices by Neighbourhood Group and Number of Bedrooms\n\n', fontsize=14, fontweight='bold');

# %% [markdown]
# Price difference based on the neighbourbood group and bedrooms is clearly visible. For most of the neighbourhood groups, higher the count of bedroom, higher is the median price.

# %%
#### Analyse is_business_travel_ready  
listings['cancellation_policy'].value_counts()
# Out:
# flexible                       9025
# moderate                       7045
# strict_14_with_grace_period    6188
# super_strict_30                  48
# super_strict_60                   9
# Name: cancellation_policy, dtype: int64

# %%
## Let's check the impact of cancellation policy on price

# group_by neighbourhood groups, take the median price and store new values in sub_df 
listings_grouped = pd.DataFrame(listings.groupby(['cancellation_policy'])['price'].agg(np.median))
listings_grouped.reset_index(inplace=True)

# plot this 
listings_grouped.sort_values(by=['price'], ascending=True)\
          .plot(kind='barh', x='cancellation_policy', y='price', 
                figsize=(9,5), legend=False, color='darkblue')

plt.xlabel('\nMedian Price', fontsize=12)
plt.ylabel('Cancellation Policy\n', fontsize=12)
plt.title('\nMedian Prices by Cancellation Policy\n', fontsize=14, fontweight='bold');

# %%
## If cancellation policy is flexible, price of the listing is lower.

# %%
## property_type analysis
listings.property_type.unique()
# Out:
# array(['Guesthouse', 'Apartment', 'Condominium', 'Loft', 'House',
#        'Serviced apartment', 'Townhouse', 'Boutique hotel',
#        'Bed and breakfast', 'Bungalow', 'Boat', 'Guest suite', 'Other',
#        'Island', 'Hostel', 'Train', 'Camper/RV', 'Houseboat', 'Cabin',
#        'Cottage', 'Tiny house', 'Chalet', 'Castle', 'Villa', 'Aparthotel',
#        'Hotel', 'Tipi', 'Resort', 'In-law', 'Cave', 'Barn',
#        'Pension (South Korea)', 'Casa particular (Cuba)'], dtype=object)

# %%
listings['property_type'].value_counts()
# Out:
# Apartment                 20098
# Condominium                 606
# Loft                        439
# House                       387
# Serviced apartment          150
# Hostel                      123
# Townhouse                    95
# Guest suite                  74
# Bed and breakfast            64
# Guesthouse                   56
# Other                        44
# Boutique hotel               36
# Hotel                        31
# Bungalow                     19
# Boat                         14
# Tiny house                   12
# Camper/RV                    11
# Villa                        10
# Houseboat                     8
# Pension (South Korea)         7
# Cabin                         6
# Aparthotel                    6
# Cottage                       4
# Resort                        3
# Castle                        2
# Train                         2
# Casa particular (Cuba)        2
# Cave                          1
# Tipi                          1
# Barn                          1
# Chalet                        1
# Island                        1
# In-law                        1
# Name: property_type, dtype: int64

# %%
freq = listings['property_type'].value_counts().sort_values(ascending=True)
freq = freq[freq > 20]  # Eliminate types less than 20 counts.
freq.plot.barh(figsize=(15, 8), width=1)
#plt.xscale('log')
plt.show()

# %%
plt.figure(figsize=(20,5))

chart=sns.boxplot(x="property_type", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=18)
plt.title('Property Type - Price distribution')
chart;

# %%
## Most of the listings are Apartment type, so we will consider only Apartment type from the listing data set

listings = listings[(listings.property_type == 'Apartment' )]

# %%
## Study of host_has_profile_pic

listings.host_has_profile_pic.unique()
# Out:
# array(['t', nan, 'f'], dtype=object)

# %%
freq = listings['host_has_profile_pic'].value_counts().sort_values(ascending=True)
freq
# Out:
# f       51
# t    20024
# Name: host_has_profile_pic, dtype: int64

# %%
## Since it is true in most of the cases, this might not be a hugely significant variable.

# %%
listings.host_identity_verified.unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
freq = listings['host_identity_verified'].value_counts().sort_values(ascending=True)
freq
# Out:
# t     7886
# f    12189
# Name: host_identity_verified, dtype: int64

# %%
## Treat or drop the variable??

# %%
plt.figure(figsize=(20,5))

chart=sns.boxplot(x="host_identity_verified", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), horizontalalignment='right', fontsize=18)
plt.title('host_identity_verified vs price distribution')
chart;

# %%
listings.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
freq = listings['room_type'].value_counts().sort_values(ascending=True)
freq.plot.barh(figsize=(10, 5), width=1)
plt.show()

# %%
## Most of the listings have room type as private room followed by Entire home/apt and Shared room

# %%
sns.boxplot(x="room_type", y="price", data=listings);

# %%
## Price does vary based on room_type

# %%
listings['accommodates'].value_counts().sort_index()
# Out:
# 1      2495
# 2     11159
# 3      2249
# 4      2805
# 5       578
# 6       538
# 7        88
# 8       104
# 9        27
# 10       25
# 11       10
# 12       17
# 13        1
# 14        1
# 15        1
# Name: accommodates, dtype: int64

# %%
## Looks like in Berlin, most of the time 2 travelers occupy a property
## So let's see if accomodates is 2 what is the impact neighbourhood group has on price.. 
## Does Average Daily price for 2 people have any dependency on the neighbourhood group?

# %%
freq = listings[listings['accommodates']==2]
freq = freq.groupby('neighbourhood_group_cleansed')['price'].mean().sort_values(ascending=True)
freq.plot.barh(figsize=(12, 8), width=1)
plt.title("Average Daily Price for 2 People")
plt.xlabel('Average Daily Price (Dollar)')
plt.ylabel("Neighbourhodd")
plt.show()

# %%
## Study number_of_reviews 

listings.plot(kind='scatter', x='number_of_reviews', y='price',alpha = 0.2,color = 'red')
plt.xlabel('number_of_reviews')              # label = name of label
plt.ylabel('price')
plt.title('number_of_reviews price Scatter Plot')            # title = title of plot
plt.show()

# %% [markdown]
# Some of the listings with less count of number of reviews have higher price and even vice versa is also true.. Some of the listings with
# high number of reviews have low price.. This is a good observation for sentiment analysis as review comment could help to analyse the sentiment

# %%
## Let us check what kind of entries are there in the variable 'experiences_offered'

listings['experiences_offered'].unique()
# Out:
# array(['none'], dtype=object)

# %% [markdown]
# We notice that the variable 'experiences_offered' has only one kind of entry so we will not be including this variable in our analysis.

# %%
## Let us check the date column. We can use this column to filter and understand how date of the hosts vary.

listings['host_since']
# Out:
# 1        16-09-2008
# 2        19-10-2008
# 3        07-11-2008
# 4        16-05-2009
# 5        25-08-2009
#             ...
# 22545    02-01-2018
# 22546    15-09-2014
# 22547    02-08-2016
# 22548    17-04-2016
# 22551    09-03-2018
# Name: host_since, Length: 20098, dtype: object

# %%
pd.DatetimeIndex(listings['host_since'])
# Out:
# DatetimeIndex(['2008-09-16', '2008-10-19', '2008-07-11', '2009-05-16',
#                '2009-08-25', '2009-11-18', '2009-03-12', '2009-12-20',
#                '2010-08-01', '2009-12-20',
#                ...
#                '2015-01-21', '2014-05-09', '2018-06-11', '2017-02-17',
#                '2013-10-20', '2018-02-01', '2014-09-15', '2016-02-08',
#                '2016-04-17', '2018-09-03'],
#               dtype='datetime64[ns]', name='host_since', length=20098, freq=None)

# %%
listings['year'] = pd.DatetimeIndex(listings['host_since']).year
listings['year']
# Out:
# 1        2008.0
# 2        2008.0
# 3        2008.0
# 4        2009.0
# 5        2009.0
#           ...
# 22545    2018.0
# 22546    2014.0
# 22547    2016.0
# 22548    2016.0
# 22551    2018.0
# Name: year, Length: 20098, dtype: float64

# %%
plt.figure(figsize=(20,5))

chart=sns.boxplot(x="year", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=18)
plt.title('Year Since price distribution')
chart;

# %%
# No specific pattern is visible between year since and price.

# %%
## is_location_exact - let's analyse this feature now

freq = listings['is_location_exact'].value_counts().sort_values(ascending=True)
freq
# Out:
# f     5237
# t    14861
# Name: is_location_exact, dtype: int64

# %%
## Most of the data points have value as Yes.

# %%
## Perfect correlation between host_total_listing_count and host_listings_count
listings[['host_total_listings_count','host_listings_count','calculated_host_listings_count']].corr()
# Out:
#                                 host_total_listings_count  \
# host_total_listings_count                        1.000000
# host_listings_count                              1.000000
# calculated_host_listings_count                   0.171816
#
#                                 host_listings_count  \
# host_total_listings_count                  1.000000
# host_listings_count                        1.000000
# calculated_host_listings_count             0.171816
#
#                                 calculated_host_listings_count
# host_total_listings_count                             0.171816
# host_listings_count                                   0.171816
# calculated_host_listings_count                        1.000000

# %%
## We should only be inlcuding either one of the perfectly correlated variables

# %%
## Analyse calculated_host_listings_count
sns.scatterplot(x='calculated_host_listings_count', y="price", data=listings, alpha=0.3);

# %%
## No clear relationship is visible with price.
## We will check how significant is 'calculated_host_listing_count' in the model

# %%
## Analysis of bathrooms
listings['bathrooms'].value_counts()
# Out:
# 1.0    17980
# 1.5      973
# 2.0      942
# 0.5       88
# 2.5       39
# 0.0       22
# 3.0       13
# 4.0        5
# 8.0        2
# 7.5        2
# 7.0        1
# 3.5        1
# Name: bathrooms, dtype: int64

# %%
# We have analysed bedrooms earlier where price was high with high count of bedrooms.. 

listings['bedrooms'].value_counts()
# Out:
# 1.0    15549
# 2.0     2615
# 0.0     1270
# 3.0      556
# 4.0       83
# 5.0       11
# 6.0        3
# Name: bedrooms, dtype: int64

# %%
## Analysis of beds
listings['beds'].value_counts()
# Out:
# 1.0     13190
# 2.0      4715
# 3.0      1153
# 4.0       588
# 5.0       189
# 6.0       124
# 7.0        38
# 8.0        34
# 0.0        20
# 9.0        10
# 10.0        7
# 12.0        3
# 15.0        2
# 11.0        1
# Name: beds, dtype: int64

# %%
listings['bed_type'].value_counts()
# Out:
# Real Bed         19390
# Pull-out Sofa      412
# Futon              212
# Couch               63
# Airbed              21
# Name: bed_type, dtype: int64

# %%
## Price does vary based on bed_type
plt.figure(figsize=(20,5))

chart=sns.boxplot(x="bed_type", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=18)
plt.title('Bed Type vs price distribution')
chart;

# %%
## Analyse guests_included

listings['guests_included'].value_counts()
# Out:
# 1     15754
# 2      3486
# 4       411
# 3       316
# 6        58
# 5        46
# 8         7
# 16        5
# 7         5
# 9         3
# 10        3
# 11        1
# 12        1
# 13        1
# 14        1
# Name: guests_included, dtype: int64

# %%
## Price does vary based on guests_included
plt.figure(figsize=(20,5))

chart=sns.boxplot(x="guests_included", y="price", data=listings, palette="viridis")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=18)
plt.title('Guests Included vs price distribution')
chart;

# %%
## Let's study the dependence of minimum nights and maximum nights with price

listings.plot(kind='scatter', x='minimum_nights', y='price',alpha = 0.5,color = 'red')
plt.xlabel('Minimum Nights')              # label = name of label
plt.ylabel('price')
plt.title('Minimum Nights vs price Scatter Plot')            # title = title of plot
plt.show()

# %%
## Let's study the dependence of minimum nights and maximum nights with price

listings.plot(kind='scatter', x='maximum_nights', y='price',alpha = 0.5,color = 'red')
plt.xlabel('Maximum Nights')              # label = name of label
plt.ylabel('price')
plt.title('Maximum Nights vs price Scatter Plot')            # title = title of plot
plt.show()

# %%
## Analyse has_availability

listings['has_availability'].value_counts()
# Out:
# t    20098
# Name: has_availability, dtype: int64

# %%
## There is no variation in this variable and thus ideally this should not be used in the model.

# %%
## availability_30 indicates how many days room is available in the next 30 day. 
## Based on availability price could vary and hence all the features related to availability will be used in the model

# %%
listings['availability_30'].value_counts()
# Out:
# 0     13444
# 6       446
# 1       413
# 4       386
# 5       346
# 29      332
# 2       318
# 3       313
# 7       279
# 8       257
# 30      257
# 9       230
# 14      196
# 12      196
# 11      195
# 23      191
# 10      187
# 27      187
# 28      186
# 15      173
# 13      164
# 16      156
# 20      156
# 17      156
# 18      155
# 19      146
# 25      144
# 22      140
# 21      135
# 24      115
# 26       99
# Name: availability_30, dtype: int64

# %%
## Let's study the review_scores_rating with price

listings.plot(kind='scatter', x='review_scores_rating', y='price',alpha = 0.5,color = 'red')
plt.xlabel('review_scores_rating ')              # label = name of label
plt.ylabel('price')
plt.title('review_scores_rating  vs price Scatter Plot')            # title = title of plot
plt.show()

# %%
## Let's also study the review_scores_value with price

sns.boxplot(x='review_scores_value',y='price',data=listings)

plt.title('review_scores_rating  vs price Box Plot')
plt.show()

# %%
## Analyse instant_bookable
listings['instant_bookable'].value_counts()
# Out:
# f    13988
# t     6110
# Name: instant_bookable, dtype: int64

# %%
#### Analyse requires_license
listings['requires_license'].value_counts()
# Out:
# t    20094
# f        4
# Name: requires_license, dtype: int64

# %%
## No variation in the 'requires_license' variable

# %%
#### Analyse is_business_travel_ready  
listings['is_business_travel_ready'].value_counts()
# Out:
# f    20098
# Name: is_business_travel_ready, dtype: int64

# %%
## No variation in the 'is_business_travel_ready' variable

# %%
#### Analyse require_guest_profile_picture
listings['require_guest_profile_picture'].value_counts()
# Out:
# f    19962
# t      136
# Name: require_guest_profile_picture, dtype: int64

# %%
#### Analyse require_guest_profile_picture
listings['require_guest_phone_verification'].value_counts()
# Out:
# f    19879
# t      219
# Name: require_guest_phone_verification, dtype: int64

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20098 entries, 1 to 22551
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                20098 non-null  int64
#  1   scrape_id                         20098 non-null  float64
#  2   last_scraped                      20098 non-null  int64
#  3   experiences_offered               20098 non-null  object
#  4   host_id                           20098 non-null  int64
#  5   host_name                         20075 non-null  object
#  6   host_since                        20075 non-null  object
#  7   host_location                     19994 non-null  object
#  8   host_is_superhost                 20098 non-null  object
#  9   host_neighbourhood                15452 non-null  object
#  10  host_listings_count               20075 non-null  float64
#  11  host_total_listings_count         20075 non-null  float64
#  12  host_verifications                20098 non-null  object
#  13  host_has_profile_pic              20075 non-null  object
#  14  host_identity_verified            20075 non-null  object
#  15  street                            20098 non-null  object
#  16  neighbourhood                     19070 non-null  object
#  17  neighbourhood_cleansed            20098 non-null  object
#  18  neighbourhood_group_cleansed      20098 non-null  object
#  19  city                              20093 non-null  object
#  20  state                             20032 non-null  object
#  21  zipcode                           19490 non-null  object
#  22  market                            20041 non-null  object
#  23  smart_location                    20098 non-null  object
#  24  country_code                      20098 non-null  object
#  25  country                           20098 non-null  object
#  26  latitude                          20098 non-null  float64
#  27  longitude                         20098 non-null  float64
#  28  is_location_exact                 20098 non-null  object
#  29  property_type                     20098 non-null  object
#  30  room_type                         20098 non-null  object
#  31  accommodates                      20098 non-null  int64
#  32  bathrooms                         20068 non-null  float64
#  33  bedrooms                          20087 non-null  float64
#  34  beds                              20074 non-null  float64
#  35  bed_type                          20098 non-null  object
#  36  amenities                         20098 non-null  object
#  37  price                             20098 non-null  float64
#  38  cleaning_fee                      20098 non-null  int32
#  39  guests_included                   20098 non-null  int64
#  40  extra_people                      20098 non-null  object
#  41  minimum_nights                    20098 non-null  int64
#  42  maximum_nights                    20098 non-null  int64
#  43  calendar_updated                  20098 non-null  object
#  44  has_availability                  20098 non-null  object
#  45  availability_30                   20098 non-null  int64
#  46  availability_60                   20098 non-null  int64
#  47  availability_90                   20098 non-null  int64
#  48  availability_365                  20098 non-null  int64
#  49  calendar_last_scraped             20098 non-null  int64
#  50  number_of_reviews                 20098 non-null  int64
#  51  first_review                      16679 non-null  float64
#  52  last_review                       16685 non-null  float64
#  53  review_scores_rating              16251 non-null  float64
#  54  review_scores_accuracy            16229 non-null  float64
#  55  review_scores_cleanliness         16231 non-null  float64
#  56  review_scores_checkin             16214 non-null  float64
#  57  review_scores_communication       16228 non-null  float64
#  58  review_scores_location            16215 non-null  float64
#  59  review_scores_value               16211 non-null  float64
#  60  requires_license                  20098 non-null  object
#  61  instant_bookable                  20098 non-null  object
#  62  is_business_travel_ready          20098 non-null  object
#  63  cancellation_policy               20098 non-null  object
#  64  require_guest_profile_picture     20098 non-null  object
#  65  require_guest_phone_verification  20098 non-null  object
#  66  calculated_host_listings_count    20098 non-null  int64
#  67  reviews_per_month                 16679 non-null  float64
#  68  dist_hbf                          20098 non-null  float64
#  69  dist_txl                          20098 non-null  float64
#  70  dist_btor                         20098 non-null  float64
#  71  dist_museum                       20098 non-null  float64
#  72  dist_reichstag                    20098 non-null  float64
#  73  dist_average                      20098 non-null  float64
#  74  Laptop_friendly_workspace         20098 non-null  bool
#  75  TV                                20098 non-null  bool
#  76  Hot water                         20098 non-null  bool
#  77  Family_friendly                   20098 non-null  bool
#  78  Hair_dryer                        20098 non-null  bool
#  79  Smoking_allowed                   20098 non-null  bool
#  80  year                              20075 non-null  float64
# dtypes: bool(6), float64(26), int32(1), int64(14), object(34)
# memory usage: 12.2+ MB

# %%
## Let's convert year into object type variable
listings['year']= listings['year'].astype(object)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20098 entries, 1 to 22551
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                20098 non-null  int64
#  1   scrape_id                         20098 non-null  float64
#  2   last_scraped                      20098 non-null  int64
#  3   experiences_offered               20098 non-null  object
#  4   host_id                           20098 non-null  int64
#  5   host_name                         20075 non-null  object
#  6   host_since                        20075 non-null  object
#  7   host_location                     19994 non-null  object
#  8   host_is_superhost                 20098 non-null  object
#  9   host_neighbourhood                15452 non-null  object
#  10  host_listings_count               20075 non-null  float64
#  11  host_total_listings_count         20075 non-null  float64
#  12  host_verifications                20098 non-null  object
#  13  host_has_profile_pic              20075 non-null  object
#  14  host_identity_verified            20075 non-null  object
#  15  street                            20098 non-null  object
#  16  neighbourhood                     19070 non-null  object
#  17  neighbourhood_cleansed            20098 non-null  object
#  18  neighbourhood_group_cleansed      20098 non-null  object
#  19  city                              20093 non-null  object
#  20  state                             20032 non-null  object
#  21  zipcode                           19490 non-null  object
#  22  market                            20041 non-null  object
#  23  smart_location                    20098 non-null  object
#  24  country_code                      20098 non-null  object
#  25  country                           20098 non-null  object
#  26  latitude                          20098 non-null  float64
#  27  longitude                         20098 non-null  float64
#  28  is_location_exact                 20098 non-null  object
#  29  property_type                     20098 non-null  object
#  30  room_type                         20098 non-null  object
#  31  accommodates                      20098 non-null  int64
#  32  bathrooms                         20068 non-null  float64
#  33  bedrooms                          20087 non-null  float64
#  34  beds                              20074 non-null  float64
#  35  bed_type                          20098 non-null  object
#  36  amenities                         20098 non-null  object
#  37  price                             20098 non-null  float64
#  38  cleaning_fee                      20098 non-null  int32
#  39  guests_included                   20098 non-null  int64
#  40  extra_people                      20098 non-null  object
#  41  minimum_nights                    20098 non-null  int64
#  42  maximum_nights                    20098 non-null  int64
#  43  calendar_updated                  20098 non-null  object
#  44  has_availability                  20098 non-null  object
#  45  availability_30                   20098 non-null  int64
#  46  availability_60                   20098 non-null  int64
#  47  availability_90                   20098 non-null  int64
#  48  availability_365                  20098 non-null  int64
#  49  calendar_last_scraped             20098 non-null  int64
#  50  number_of_reviews                 20098 non-null  int64
#  51  first_review                      16679 non-null  float64
#  52  last_review                       16685 non-null  float64
#  53  review_scores_rating              16251 non-null  float64
#  54  review_scores_accuracy            16229 non-null  float64
#  55  review_scores_cleanliness         16231 non-null  float64
#  56  review_scores_checkin             16214 non-null  float64
#  57  review_scores_communication       16228 non-null  float64
#  58  review_scores_location            16215 non-null  float64
#  59  review_scores_value               16211 non-null  float64
#  60  requires_license                  20098 non-null  object
#  61  instant_bookable                  20098 non-null  object
#  62  is_business_travel_ready          20098 non-null  object
#  63  cancellation_policy               20098 non-null  object
#  64  require_guest_profile_picture     20098 non-null  object
#  65  require_guest_phone_verification  20098 non-null  object
#  66  calculated_host_listings_count    20098 non-null  int64
#  67  reviews_per_month                 16679 non-null  float64
#  68  dist_hbf                          20098 non-null  float64
#  69  dist_txl                          20098 non-null  float64
#  70  dist_btor                         20098 non-null  float64
#  71  dist_museum                       20098 non-null  float64
#  72  dist_reichstag                    20098 non-null  float64
#  73  dist_average                      20098 non-null  float64
#  74  Laptop_friendly_workspace         20098 non-null  bool
#  75  TV                                20098 non-null  bool
#  76  Hot water                         20098 non-null  bool
#  77  Family_friendly                   20098 non-null  bool
#  78  Hair_dryer                        20098 non-null  bool
#  79  Smoking_allowed                   20098 non-null  bool
#  80  year                              20075 non-null  object
# dtypes: bool(6), float64(25), int32(1), int64(14), object(35)
# memory usage: 12.2+ MB

# %%
listings = pd.get_dummies(listings, columns=['host_is_superhost','host_identity_verified','neighbourhood_group_cleansed','is_location_exact','property_type','room_type','bed_type','instant_bookable','cancellation_policy','Laptop_friendly_workspace','TV','Hot water','Family_friendly','Hair_dryer','Smoking_allowed','year'],drop_first=True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20098 entries, 1 to 22551
# Columns: 105 entries, id to year_2018.0
# dtypes: float64(25), int32(1), int64(14), object(25), uint8(40)
# memory usage: 11.3+ MB

# %%
listings.rename(columns = {'neighbourhood_group_cleansed_Marzahn - Hellersdorf':'neighbourhood_group_cleansed_Marzahn_Hellersdorf','neighbourhood_group_cleansed_Steglitz - Zehlendorf':'neighbourhood_group_cleansed_Steglitz_Zehlendorf','neighbourhood_group_cleansed_Tempelhof - Schöneberg':'neighbourhood_group_cleansed_Tempelhof_Schöneberg', 'neighbourhood_group_cleansed_Treptow - Köpenick':'neighbourhood_group_cleansed_Treptow_Köpenick','bed_type_Pull-out Sofa':'bed_type_Pull_out_Sofa', 'bed_type_Real Bed':'bed_type_Real_Bed','room_type_Private room':'room_type_Private_room','room_type_Shared room':'room_type_Shared_room','Hot water_True':'Hot_water_True', 'year_2009.0':'year_2009','year_2010.0':'year_2010','year_2011.0':'year_2011','year_2012.0':'year_2012','year_2013.0':'year_2013','year_2014.0':'year_2014','year_2015.0':'year_2015','year_2016.0':'year_2016','year_2017.0':'year_2017','year_2018.0':'year_2018'}, inplace=True)

# %%
listings_new = listings[['host_total_listings_count','accommodates','guests_included','availability_30','availability_60',
'availability_90','availability_365','number_of_reviews','review_scores_rating','review_scores_accuracy',
'review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location',
'review_scores_value','calculated_host_listings_count','dist_average','bathrooms','bedrooms',
'host_is_superhost_t','host_identity_verified_t','neighbourhood_group_cleansed_Lichtenberg',
'neighbourhood_group_cleansed_Mitte','neighbourhood_group_cleansed_Neukölln',
'neighbourhood_group_cleansed_Tempelhof_Schöneberg','neighbourhood_group_cleansed_Treptow_Köpenick',
'neighbourhood_group_cleansed_Steglitz_Zehlendorf','neighbourhood_group_cleansed_Pankow',
'neighbourhood_group_cleansed_Marzahn_Hellersdorf','neighbourhood_group_cleansed_Reinickendorf',
'neighbourhood_group_cleansed_Spandau','is_location_exact_t','room_type_Private_room','room_type_Shared_room',                               
'bed_type_Couch','bed_type_Futon','bed_type_Pull_out_Sofa','bed_type_Real_Bed','instant_bookable_t',
'cancellation_policy_moderate','cancellation_policy_strict_14_with_grace_period','cancellation_policy_super_strict_30',
'cancellation_policy_super_strict_60','Laptop_friendly_workspace_True','TV_True','Hot_water_True','Family_friendly_True',
'Smoking_allowed_True','year_2009','year_2010','year_2011','year_2012','year_2013','year_2014','year_2015','year_2016',
'year_2017','year_2018','price']]

# %%
listings_new.isna().sum()
# Out:
# host_total_listings_count                              23
# accommodates                                            0
# guests_included                                         0
# availability_30                                         0
# availability_60                                         0
# availability_90                                         0
# availability_365                                        0
# number_of_reviews                                       0
# review_scores_rating                                 3847
# review_scores_accuracy                               3869
# review_scores_cleanliness                            3867
# review_scores_checkin                                3884
# review_scores_communication                          3870
# review_scores_location                               3883
# review_scores_value                                  3887
# calculated_host_listings_count                          0
# dist_average                                            0
# bathrooms                                              30
# bedrooms                                               11
# host_is_superhost_t                                     0
# host_identity_verified_t                                0
# neighbourhood_group_cleansed_Lichtenberg                0
# neighbourhood_group_cleansed_Mitte                      0
# neighbourhood_group_cleansed_Neukölln                   0
# neighbourhood_group_cleansed_Tempelhof_Schöneberg       0
# neighbourhood_group_cleansed_Treptow_Köpenick           0
# neighbourhood_group_cleansed_Steglitz_Zehlendorf        0
# neighbourhood_group_cleansed_Pankow                     0
# neighbourhood_group_cleansed_Marzahn_Hellersdorf        0
# neighbourhood_group_cleansed_Reinickendorf              0
# neighbourhood_group_cleansed_Spandau                    0
# is_location_exact_t                                     0
# room_type_Private_room                                  0
# room_type_Shared_room                                   0
# bed_type_Couch                                          0
# bed_type_Futon                                          0
# bed_type_Pull_out_Sofa                                  0
# bed_type_Real_Bed                                       0
# instant_bookable_t                                      0
# cancellation_policy_moderate                            0
# cancellation_policy_strict_14_with_grace_period         0
# cancellation_policy_super_strict_30                     0
# cancellation_policy_super_strict_60                     0
# Laptop_friendly_workspace_True                          0
# TV_True                                                 0
# Hot_water_True                                          0
# Family_friendly_True                                    0
# Smoking_allowed_True                                    0
# year_2009                                               0
# year_2010                                               0
# year_2011                                               0
# year_2012                                               0
# year_2013                                               0
# year_2014                                               0
# year_2015                                               0
# year_2016                                               0
# year_2017                                               0
# year_2018                                               0
# price                                                   0
# dtype: int64

# %%
## We will drop host_neighbourhood as inputation of this object type of variable using mode will not be accurate from analysis perspective
## If we use drop na then we will loose lot of rows wherein we do have data points for other feature hence drop na without imputation 
## and /or deleting the columns is not recommended
## All features pertaining to review with missing values, imputation would be done using median

listings_new["review_scores_value"].replace(np.nan,listings_new["review_scores_value"].median(),inplace=True)
listings_new["review_scores_checkin"].replace(np.nan,listings_new["review_scores_checkin"].median(),inplace=True)
listings_new["review_scores_location"].replace(np.nan,listings_new["review_scores_location"].median(),inplace=True)
listings_new["review_scores_communication"].replace(np.nan,listings_new["review_scores_communication"].median(),inplace=True)
listings_new["review_scores_accuracy"].replace(np.nan,listings_new["review_scores_accuracy"].median(),inplace=True)
listings_new["review_scores_cleanliness"].replace(np.nan,listings_new["review_scores_cleanliness"].median(),inplace=True)
listings_new["review_scores_rating"].replace(np.nan,listings_new["review_scores_rating"].median(),inplace=True)
# Out:
# C:\Users\91976\anaconda3\lib\site-packages\pandas\core\series.py:4479: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
listings_new.isna().sum()
# Out:
# host_total_listings_count                            23
# accommodates                                          0
# guests_included                                       0
# availability_30                                       0
# availability_60                                       0
# availability_90                                       0
# availability_365                                      0
# number_of_reviews                                     0
# review_scores_rating                                  0
# review_scores_accuracy                                0
# review_scores_cleanliness                             0
# review_scores_checkin                                 0
# review_scores_communication                           0
# review_scores_location                                0
# review_scores_value                                   0
# calculated_host_listings_count                        0
# dist_average                                          0
# bathrooms                                            30
# bedrooms                                             11
# host_is_superhost_t                                   0
# host_identity_verified_t                              0
# neighbourhood_group_cleansed_Lichtenberg              0
# neighbourhood_group_cleansed_Mitte                    0
# neighbourhood_group_cleansed_Neukölln                 0
# neighbourhood_group_cleansed_Tempelhof_Schöneberg     0
# neighbourhood_group_cleansed_Treptow_Köpenick         0
# neighbourhood_group_cleansed_Steglitz_Zehlendorf      0
# neighbourhood_group_cleansed_Pankow                   0
# neighbourhood_group_cleansed_Marzahn_Hellersdorf      0
# neighbourhood_group_cleansed_Reinickendorf            0
# neighbourhood_group_cleansed_Spandau                  0
# is_location_exact_t                                   0
# room_type_Private_room                                0
# room_type_Shared_room                                 0
# bed_type_Couch                                        0
# bed_type_Futon                                        0
# bed_type_Pull_out_Sofa                                0
# bed_type_Real_Bed                                     0
# instant_bookable_t                                    0
# cancellation_policy_moderate                          0
# cancellation_policy_strict_14_with_grace_period       0
# cancellation_policy_super_strict_30                   0
# cancellation_policy_super_strict_60                   0
# Laptop_friendly_workspace_True                        0
# TV_True                                               0
# Hot_water_True                                        0
# Family_friendly_True                                  0
# Smoking_allowed_True                                  0
# year_2009                                             0
# year_2010                                             0
# year_2011                                             0
# year_2012                                             0
# year_2013                                             0
# year_2014                                             0
# year_2015                                             0
# year_2016                                             0
# year_2017                                             0
# year_2018                                             0
# price                                                 0
# dtype: int64

# %%
## Let's drop these missing values 
listings_new.dropna(axis=0, inplace=True)

## Discussion whether to drop the missing values or impute the missing values
# Out:
# <ipython-input-107-404a447e33ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_new.dropna(axis=0, inplace=True)

# %%
listings_new.isna().sum()
# Out:
# host_total_listings_count                            0
# accommodates                                         0
# guests_included                                      0
# availability_30                                      0
# availability_60                                      0
# availability_90                                      0
# availability_365                                     0
# number_of_reviews                                    0
# review_scores_rating                                 0
# review_scores_accuracy                               0
# review_scores_cleanliness                            0
# review_scores_checkin                                0
# review_scores_communication                          0
# review_scores_location                               0
# review_scores_value                                  0
# calculated_host_listings_count                       0
# dist_average                                         0
# bathrooms                                            0
# bedrooms                                             0
# host_is_superhost_t                                  0
# host_identity_verified_t                             0
# neighbourhood_group_cleansed_Lichtenberg             0
# neighbourhood_group_cleansed_Mitte                   0
# neighbourhood_group_cleansed_Neukölln                0
# neighbourhood_group_cleansed_Tempelhof_Schöneberg    0
# neighbourhood_group_cleansed_Treptow_Köpenick        0
# neighbourhood_group_cleansed_Steglitz_Zehlendorf     0
# neighbourhood_group_cleansed_Pankow                  0
# neighbourhood_group_cleansed_Marzahn_Hellersdorf     0
# neighbourhood_group_cleansed_Reinickendorf           0
# neighbourhood_group_cleansed_Spandau                 0
# is_location_exact_t                                  0
# room_type_Private_room                               0
# room_type_Shared_room                                0
# bed_type_Couch                                       0
# bed_type_Futon                                       0
# bed_type_Pull_out_Sofa                               0
# bed_type_Real_Bed                                    0
# instant_bookable_t                                   0
# cancellation_policy_moderate                         0
# cancellation_policy_strict_14_with_grace_period      0
# cancellation_policy_super_strict_30                  0
# cancellation_policy_super_strict_60                  0
# Laptop_friendly_workspace_True                       0
# TV_True                                              0
# Hot_water_True                                       0
# Family_friendly_True                                 0
# Smoking_allowed_True                                 0
# year_2009                                            0
# year_2010                                            0
# year_2011                                            0
# year_2012                                            0
# year_2013                                            0
# year_2014                                            0
# year_2015                                            0
# year_2016                                            0
# year_2017                                            0
# year_2018                                            0
# price                                                0
# dtype: int64

# %%
# Split the data into training and test set in 70:30 ratio

from sklearn.model_selection import train_test_split

Train, Test = train_test_split(listings_new, test_size=0.30 , random_state=1)

# %%
from IPython.display import display

# %%
display(Train.head())

print(Train.shape)
# Out:
#        host_total_listings_count  accommodates  guests_included  \
# 13984                        1.0             2                1
# 19097                        3.0             2                1
# 9454                         1.0             1                1
# 18767                        1.0             2                1
# 2456                         1.0             2                1
#
#        availability_30  availability_60  availability_90  availability_365  \
# 13984                0                0                0                 0
# 19097                0                0                0                 0
# 9454                 0                0                0                 0
# 18767                0                0                0                 0
# 2456                 0                0                0                 0
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 13984                  2                  80.0                     9.0
# 19097                  2                 100.0                    10.0
# 9454                   1                 100.0                    10.0
# 18767                  2                 100.0                    10.0
# 2456                   6                  93.0                     9.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 13984                        6.0                    9.0
# 19097                       10.0                   10.0
# 9454                        10.0                   10.0
# 18767                       10.0                   10.0
# 2456                         9.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 13984                         10.0                     8.0
# 19097                         10.0                    10.0
# 9454                          10.0                    10.0
# 18767                         10.0                    10.0
# 2456                           9.0                     9.0
#
#        review_scores_value  calculated_host_listings_count  dist_average  \
# 13984                  8.0                               1      3.890794
# 19097                 10.0                               1      3.213830
# 9454                  10.0                               1      7.265014
# 18767                 10.0                               1      7.155850
# 2456                   9.0                               1      5.923596
#
#        bathrooms  bedrooms  host_is_superhost_t  host_identity_verified_t  \
# 13984        1.5       1.0                    0                         0
# 19097        1.0       1.0                    0                         1
# 9454         1.0       1.0                    0                         0
# 18767        1.0       1.0                    0                         1
# 2456         1.0       1.0                    0                         0
#
#        neighbourhood_group_cleansed_Lichtenberg  \
# 13984                                         0
# 19097                                         0
# 9454                                          0
# 18767                                         0
# 2456                                          0
#
#        neighbourhood_group_cleansed_Mitte  \
# 13984                                   1
# 19097                                   1
# 9454                                    0
# 18767                                   0
# 2456                                    0
#
#        neighbourhood_group_cleansed_Neukölln  \
# 13984                                      0
# 19097                                      0
# 9454                                       0
# 18767                                      1
# 2456                                       1
#
#        neighbourhood_group_cleansed_Tempelhof_Schöneberg  \
# 13984                                                  0
# 19097                                                  0
# 9454                                                   0
# 18767                                                  0
# 2456                                                   0
#
#        neighbourhood_group_cleansed_Treptow_Köpenick  \
# 13984                                              0
# 19097                                              0
# 9454                                               0
# 18767                                              0
# 2456                                               0
#
#        neighbourhood_group_cleansed_Steglitz_Zehlendorf  \
# 13984                                                 0
# 19097                                                 0
# 9454                                                  0
# 18767                                                 0
# 2456                                                  0
#
#        neighbourhood_group_cleansed_Pankow  \
# 13984                                    0
# 19097                                    0
# 9454                                     0
# 18767                                    0
# 2456                                     0
#
#        neighbourhood_group_cleansed_Marzahn_Hellersdorf  \
# 13984                                                 0
# 19097                                                 0
# 9454                                                  0
# 18767                                                 0
# 2456                                                  0
#
#        neighbourhood_group_cleansed_Reinickendorf  \
# 13984                                           0
# 19097                                           0
# 9454                                            0
# 18767                                           0
# 2456                                            0
#
#        neighbourhood_group_cleansed_Spandau  is_location_exact_t  \
# 13984                                     0                    1
# 19097                                     0                    0
# 9454                                      0                    1
# 18767                                     0                    1
# 2456                                      0                    1
#
#        room_type_Private_room  room_type_Shared_room  bed_type_Couch  \
# 13984                       1                      0               0
# 19097                       1                      0               0
# 9454                        1                      0               0
# 18767                       0                      0               0
# 2456                        1                      0               0
#
#        bed_type_Futon  bed_type_Pull_out_Sofa  bed_type_Real_Bed  \
# 13984               0                       0                  1
# 19097               0                       0                  1
# 9454                0                       0                  1
# 18767               0                       0                  1
# 2456                0                       0                  1
#
#        instant_bookable_t  cancellation_policy_moderate  \
# 13984                   0                             0
# 19097                   0                             0
# 9454                    0                             0
# 18767                   0                             0
# 2456                    0                             0
#
#        cancellation_policy_strict_14_with_grace_period  \
# 13984                                                0
# 19097                                                0
# 9454                                                 1
# 18767                                                1
# 2456                                                 0
#
#        cancellation_policy_super_strict_30  \
# 13984                                    0
# 19097                                    0
# 9454                                     0
# 18767                                    0
# 2456                                     0
#
#        cancellation_policy_super_strict_60  Laptop_friendly_workspace_True  \
# 13984                                    0                               1
# 19097                                    0                               1
# 9454                                     0                               1
# 18767                                    0                               1
# 2456                                     0                               1
#
#        TV_True  Hot_water_True  Family_friendly_True  Smoking_allowed_True  \
# 13984        0               1                     0                     1
# 19097        1               1                     0                     0
# 9454         0               0                     0                     1
# 18767        0               0                     0                     0
# 2456         0               0                     0                     1
#
#        year_2009  year_2010  year_2011  year_2012  year_2013  year_2014  \
# 13984          0          0          0          0          0          0
# 19097          0          0          0          0          0          1
# 9454           0          0          0          0          0          1
# 18767          0          0          0          0          0          0
# 2456           0          0          0          0          0          1
#
#        year_2015  year_2016  year_2017  year_2018  price
# 13984          0          1          0          0   20.0
# 19097          0          0          0          0   35.0
# 9454           0          0          0          0   25.0
# 18767          0          1          0          0   60.0
# 2456           0          0          0          0   29.0
# (14023, 59)

# %%
display(Test.head())

print(Test.shape)
# Out:
#        host_total_listings_count  accommodates  guests_included  \
# 14914                        2.0             4                2
# 16489                        1.0             1                1
# 4326                         1.0             4                2
# 975                          1.0             2                1
# 12948                        1.0             2                1
#
#        availability_30  availability_60  availability_90  availability_365  \
# 14914               21               48               74               264
# 16489                0                0                0                 0
# 4326                 0                0                0                 0
# 975                 19               49               59                59
# 12948                9                9                9                 9
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 14914                 58                  95.0                    10.0
# 16489                  5                  96.0                    10.0
# 4326                   9                  89.0                     9.0
# 975                   40                  96.0                    10.0
# 12948                 67                  99.0                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 14914                       10.0                   10.0
# 16489                       10.0                   10.0
# 4326                        10.0                    9.0
# 975                         10.0                   10.0
# 12948                       10.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 14914                         10.0                    10.0
# 16489                         10.0                    10.0
# 4326                          10.0                     9.0
# 975                           10.0                     9.0
# 12948                         10.0                    10.0
#
#        review_scores_value  calculated_host_listings_count  dist_average  \
# 14914                  9.0                               1      4.510624
# 16489                 10.0                               1      3.321683
# 4326                   8.0                               1      6.930379
# 975                   10.0                               1      3.452970
# 12948                 10.0                               1      3.615030
#
#        bathrooms  bedrooms  host_is_superhost_t  host_identity_verified_t  \
# 14914        1.0       1.0                    1                         0
# 16489        2.0       1.0                    0                         0
# 4326         1.0       1.0                    0                         1
# 975          1.0       1.0                    0                         1
# 12948        1.0       1.0                    1                         0
#
#        neighbourhood_group_cleansed_Lichtenberg  \
# 14914                                         0
# 16489                                         0
# 4326                                          0
# 975                                           0
# 12948                                         0
#
#        neighbourhood_group_cleansed_Mitte  \
# 14914                                   0
# 16489                                   0
# 4326                                    0
# 975                                     1
# 12948                                   0
#
#        neighbourhood_group_cleansed_Neukölln  \
# 14914                                      0
# 16489                                      0
# 4326                                       0
# 975                                        0
# 12948                                      0
#
#        neighbourhood_group_cleansed_Tempelhof_Schöneberg  \
# 14914                                                  0
# 16489                                                  0
# 4326                                                   0
# 975                                                    0
# 12948                                                  0
#
#        neighbourhood_group_cleansed_Treptow_Köpenick  \
# 14914                                              0
# 16489                                              0
# 4326                                               0
# 975                                                0
# 12948                                              0
#
#        neighbourhood_group_cleansed_Steglitz_Zehlendorf  \
# 14914                                                 0
# 16489                                                 0
# 4326                                                  0
# 975                                                   0
# 12948                                                 0
#
#        neighbourhood_group_cleansed_Pankow  \
# 14914                                    1
# 16489                                    0
# 4326                                     0
# 975                                      0
# 12948                                    1
#
#        neighbourhood_group_cleansed_Marzahn_Hellersdorf  \
# 14914                                                 0
# 16489                                                 0
# 4326                                                  0
# 975                                                   0
# 12948                                                 0
#
#        neighbourhood_group_cleansed_Reinickendorf  \
# 14914                                           0
# 16489                                           0
# 4326                                            0
# 975                                             0
# 12948                                           0
#
#        neighbourhood_group_cleansed_Spandau  is_location_exact_t  \
# 14914                                     0                    0
# 16489                                     0                    1
# 4326                                      0                    1
# 975                                       0                    1
# 12948                                     0                    1
#
#        room_type_Private_room  room_type_Shared_room  bed_type_Couch  \
# 14914                       0                      0               0
# 16489                       1                      0               0
# 4326                        0                      0               0
# 975                         0                      0               0
# 12948                       1                      0               0
#
#        bed_type_Futon  bed_type_Pull_out_Sofa  bed_type_Real_Bed  \
# 14914               0                       0                  1
# 16489               0                       0                  1
# 4326                0                       0                  1
# 975                 0                       0                  1
# 12948               0                       0                  1
#
#        instant_bookable_t  cancellation_policy_moderate  \
# 14914                   1                             0
# 16489                   1                             0
# 4326                    0                             0
# 975                     0                             0
# 12948                   0                             1
#
#        cancellation_policy_strict_14_with_grace_period  \
# 14914                                                1
# 16489                                                0
# 4326                                                 1
# 975                                                  1
# 12948                                                0
#
#        cancellation_policy_super_strict_30  \
# 14914                                    0
# 16489                                    0
# 4326                                     0
# 975                                      0
# 12948                                    0
#
#        cancellation_policy_super_strict_60  Laptop_friendly_workspace_True  \
# 14914                                    0                               1
# 16489                                    0                               0
# 4326                                     0                               1
# 975                                      0                               1
# 12948                                    0                               1
#
#        TV_True  Hot_water_True  Family_friendly_True  Smoking_allowed_True  \
# 14914        0               1                     1                     0
# 16489        1               0                     0                     0
# 4326         1               1                     1                     1
# 975          1               0                     0                     0
# 12948        0               1                     0                     0
#
#        year_2009  year_2010  year_2011  year_2012  year_2013  year_2014  \
# 14914          0          0          0          0          0          0
# 16489          0          0          0          0          0          0
# 4326           0          0          0          1          0          0
# 975            0          0          0          0          1          0
# 12948          0          0          0          0          0          0
#
#        year_2015  year_2016  year_2017  year_2018  price
# 14914          0          0          1          0   49.0
# 16489          0          0          1          0   39.0
# 4326           0          0          0          0  100.0
# 975            0          0          0          0   29.0
# 12948          0          0          1          0   35.0
# (6011, 59)

# %%
import statsmodels.formula.api as smf
lm1 = smf.ols(formula= 'price ~ host_total_listings_count+accommodates+guests_included+availability_30+availability_60+availability_90+availability_365+number_of_reviews+review_scores_rating+review_scores_accuracy+review_scores_cleanliness+review_scores_checkin+review_scores_communication+review_scores_location+review_scores_value+calculated_host_listings_count+dist_average+bathrooms+bedrooms+host_is_superhost_t+host_identity_verified_t+neighbourhood_group_cleansed_Lichtenberg++neighbourhood_group_cleansed_Mitte+neighbourhood_group_cleansed_Neukölln+neighbourhood_group_cleansed_Tempelhof_Schöneberg+neighbourhood_group_cleansed_Treptow_Köpenick+neighbourhood_group_cleansed_Steglitz_Zehlendorf+neighbourhood_group_cleansed_Pankow+neighbourhood_group_cleansed_Marzahn_Hellersdorf+neighbourhood_group_cleansed_Reinickendorf+neighbourhood_group_cleansed_Spandau+is_location_exact_t+room_type_Private_room+room_type_Shared_room+bed_type_Couch+bed_type_Futon+bed_type_Pull_out_Sofa+bed_type_Real_Bed+instant_bookable_t+cancellation_policy_moderate+cancellation_policy_strict_14_with_grace_period+cancellation_policy_super_strict_30+cancellation_policy_super_strict_60+Laptop_friendly_workspace_True+TV_True+Hot_water_True+Family_friendly_True+Smoking_allowed_True+year_2009+year_2010+year_2011+year_2012+year_2013+year_2014+year_2015+year_2016+year_2017+year_2018',data = Train).fit()
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     249.8
# Date:                Sat, 06 Feb 2021   Prob (F-statistic):               0.00
# Time:                        04:16:01   Log-Likelihood:                -64724.
# No. Observations:               14023   AIC:                         1.296e+05
# Df Residuals:                   13964   BIC:                         1.300e+05
# Df Model:                          58
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                            -7.1538     15.933     -0.449      0.653     -38.384      24.076
# host_total_listings_count                            -0.0008      0.008     -0.090      0.928      -0.017       0.016
# accommodates                                          6.5492      0.234     27.939      0.000       6.090       7.009
# guests_included                                       4.9096      0.332     14.767      0.000       4.258       5.561
# availability_30                                       0.3676      0.075      4.908      0.000       0.221       0.514
# availability_60                                       0.0575      0.061      0.937      0.349      -0.063       0.178
# availability_90                                       0.0633      0.028      2.222      0.026       0.007       0.119
# availability_365                                      0.0046      0.003      1.710      0.087      -0.001       0.010
# number_of_reviews                                    -0.0534      0.007     -7.901      0.000      -0.067      -0.040
# review_scores_rating                                  0.2249      0.051      4.416      0.000       0.125       0.325
# review_scores_accuracy                               -0.3845      0.439     -0.876      0.381      -1.245       0.476
# review_scores_cleanliness                             1.9562      0.300      6.513      0.000       1.367       2.545
# review_scores_checkin                                 0.1715      0.443      0.387      0.699      -0.697       1.040
# review_scores_communication                          -0.5479      0.464     -1.180      0.238      -1.458       0.362
# review_scores_location                                2.9094      0.347      8.386      0.000       2.229       3.589
# review_scores_value                                  -3.4159      0.403     -8.485      0.000      -4.205      -2.627
# calculated_host_listings_count                       -0.3774      0.110     -3.418      0.001      -0.594      -0.161
# dist_average                                         -2.0714      0.155    -13.372      0.000      -2.375      -1.768
# bathrooms                                            10.4884      0.786     13.350      0.000       8.948      12.028
# bedrooms                                              8.8111      0.462     19.057      0.000       7.905       9.717
# host_is_superhost_t                                   4.0403      0.696      5.803      0.000       2.676       5.405
# host_identity_verified_t                             -0.0833      0.464     -0.179      0.858      -0.993       0.827
# neighbourhood_group_cleansed_Lichtenberg             -0.2610      1.360     -0.192      0.848      -2.928       2.406
# neighbourhood_group_cleansed_Mitte                   -2.2432      0.688     -3.259      0.001      -3.592      -0.894
# neighbourhood_group_cleansed_Neukölln                -0.9504      0.687     -1.383      0.167      -2.297       0.397
# neighbourhood_group_cleansed_Tempelhof_Schöneberg    -2.9428      0.874     -3.366      0.001      -4.657      -1.229
# neighbourhood_group_cleansed_Treptow_Köpenick         1.2195      1.686      0.723      0.470      -2.086       4.525
# neighbourhood_group_cleansed_Steglitz_Zehlendorf     -2.5772      1.809     -1.425      0.154      -6.123       0.968
# neighbourhood_group_cleansed_Pankow                  -0.9842      0.650     -1.515      0.130      -2.257       0.289
# neighbourhood_group_cleansed_Marzahn_Hellersdorf      1.6448      3.857      0.426      0.670      -5.916       9.205
# neighbourhood_group_cleansed_Reinickendorf          -12.7953      2.152     -5.946      0.000     -17.013      -8.577
# neighbourhood_group_cleansed_Spandau                 -8.1104      3.524     -2.302      0.021     -15.017      -1.204
# is_location_exact_t                                  -0.3943      0.477     -0.827      0.408      -1.329       0.540
# room_type_Private_room                              -20.0928      0.501    -40.070      0.000     -21.076     -19.110
# room_type_Shared_room                               -23.6698      2.143    -11.043      0.000     -27.871     -19.468
# bed_type_Couch                                      -10.3811      6.992     -1.485      0.138     -24.087       3.325
# bed_type_Futon                                      -10.7764      6.302     -1.710      0.087     -23.128       1.576
# bed_type_Pull_out_Sofa                               -9.7914      6.130     -1.597      0.110     -21.807       2.224
# bed_type_Real_Bed                                    -7.8210      5.963     -1.312      0.190     -19.510       3.868
# instant_bookable_t                                    1.0484      0.475      2.205      0.027       0.116       1.980
# cancellation_policy_moderate                          0.6024      0.513      1.174      0.240      -0.403       1.608
# cancellation_policy_strict_14_with_grace_period       2.0343      0.565      3.600      0.000       0.927       3.142
# cancellation_policy_super_strict_30                 -20.6794      6.258     -3.305      0.001     -32.946      -8.413
# cancellation_policy_super_strict_60                   3.7626     24.572      0.153      0.878     -44.402      51.927
# Laptop_friendly_workspace_True                        1.2466      0.454      2.745      0.006       0.356       2.137
# TV_True                                               5.0369      0.456     11.037      0.000       4.142       5.931
# Hot_water_True                                       -0.3010      0.476     -0.633      0.527      -1.233       0.631
# Family_friendly_True                                  1.3030      0.485      2.688      0.007       0.353       2.253
# Smoking_allowed_True                                 -2.1100      0.526     -4.011      0.000      -3.141      -1.079
# year_2009                                            21.4611     14.996      1.431      0.152      -7.933      50.856
# year_2010                                            14.9607     14.317      1.045      0.296     -13.102      43.024
# year_2011                                            16.1471     14.207      1.137      0.256     -11.700      43.994
# year_2012                                            17.0212     14.192      1.199      0.230     -10.797      44.839
# year_2013                                            16.5267     14.187      1.165      0.244     -11.281      44.335
# year_2014                                            15.6973     14.186      1.107      0.268     -12.108      43.503
# year_2015                                            13.9271     14.186      0.982      0.326     -13.880      41.734
# year_2016                                            13.9807     14.189      0.985      0.324     -13.832      41.793
# year_2017                                            15.1948     14.197      1.070      0.285     -12.633      43.023
# year_2018                                            16.0132     14.207      1.127      0.260     -11.834      43.861
# ==============================================================================
# Omnibus:                     6150.842   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56140.549
# Skew:                           1.875   Prob(JB):                         0.00
# Kurtosis:                      12.056   Cond. No.                     3.51e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#####################Iteration 2 ###### How do we improve the model??

# %%
## let's check the vif value

def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=smf.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(input_data=Train.drop('price',axis=1))
# Out:
# host_total_listings_count  VIF =  1.04
# accommodates  VIF =  2.3
# guests_included  VIF =  1.37
# availability_30  VIF =  8.97
# availability_60  VIF =  24.57
# availability_90  VIF =  14.01
# availability_365  VIF =  2.24
# number_of_reviews  VIF =  1.4
# review_scores_rating  VIF =  3.01
# review_scores_accuracy  VIF =  2.14
# review_scores_cleanliness  VIF =  1.99
# review_scores_checkin  VIF =  1.92
# review_scores_communication  VIF =  1.97
# review_scores_location  VIF =  1.44
# review_scores_value  VIF =  2.44
# calculated_host_listings_count  VIF =  2.67
# dist_average  VIF =  3.0
# bathrooms  VIF =  1.07
# bedrooms  VIF =  1.68
# host_is_superhost_t  VIF =  1.25
# host_identity_verified_t  VIF =  1.2
# neighbourhood_group_cleansed_Lichtenberg  VIF =  1.24
# neighbourhood_group_cleansed_Mitte  VIF =  1.81
# neighbourhood_group_cleansed_Neukölln  VIF =  1.52
# neighbourhood_group_cleansed_Tempelhof_Schöneberg  VIF =  1.15
# neighbourhood_group_cleansed_Treptow_Köpenick  VIF =  1.5
# neighbourhood_group_cleansed_Steglitz_Zehlendorf  VIF =  1.25
# neighbourhood_group_cleansed_Pankow  VIF =  1.31
# neighbourhood_group_cleansed_Marzahn_Hellersdorf  VIF =  1.16
# neighbourhood_group_cleansed_Reinickendorf  VIF =  1.04
# neighbourhood_group_cleansed_Spandau  VIF =  1.11
# is_location_exact_t  VIF =  1.03
# room_type_Private_room  VIF =  1.46
# room_type_Shared_room  VIF =  1.04
# bed_type_Couch  VIF =  3.65
# bed_type_Futon  VIF =  9.43
# bed_type_Pull_out_Sofa  VIF =  17.84
# bed_type_Real_Bed  VIF =  28.4
# instant_bookable_t  VIF =  1.12
# cancellation_policy_moderate  VIF =  1.33
# cancellation_policy_strict_14_with_grace_period  VIF =  1.45
# cancellation_policy_super_strict_30  VIF =  2.47
# cancellation_policy_super_strict_60  VIF =  1.01
# Laptop_friendly_workspace_True  VIF =  1.11
# TV_True  VIF =  1.19
# Hot_water_True  VIF =  1.28
# Family_friendly_True  VIF =  1.24
# Smoking_allowed_True  VIF =  1.09
# year_2009  VIF =  9.35
# year_2010  VIF =  48.99
# year_2011  VIF =  193.08
# year_2012  VIF =  365.35
# year_2013  VIF =  528.47
# year_2014  VIF =  678.6
# year_2015  VIF =  780.66
# year_2016  VIF =  635.76
# year_2017  VIF =  469.37
# year_2018  VIF =  315.68

# %%
vif_cal(input_data=Train.drop(['price','availability_60'],axis=1))
# Out:
# host_total_listings_count  VIF =  1.04
# accommodates  VIF =  2.3
# guests_included  VIF =  1.37
# availability_30  VIF =  3.86
# availability_90  VIF =  5.4
# availability_365  VIF =  2.2
# number_of_reviews  VIF =  1.4
# review_scores_rating  VIF =  3.01
# review_scores_accuracy  VIF =  2.14
# review_scores_cleanliness  VIF =  1.99
# review_scores_checkin  VIF =  1.92
# review_scores_communication  VIF =  1.97
# review_scores_location  VIF =  1.44
# review_scores_value  VIF =  2.44
# calculated_host_listings_count  VIF =  2.67
# dist_average  VIF =  3.0
# bathrooms  VIF =  1.07
# bedrooms  VIF =  1.68
# host_is_superhost_t  VIF =  1.25
# host_identity_verified_t  VIF =  1.2
# neighbourhood_group_cleansed_Lichtenberg  VIF =  1.24
# neighbourhood_group_cleansed_Mitte  VIF =  1.81
# neighbourhood_group_cleansed_Neukölln  VIF =  1.52
# neighbourhood_group_cleansed_Tempelhof_Schöneberg  VIF =  1.15
# neighbourhood_group_cleansed_Treptow_Köpenick  VIF =  1.5
# neighbourhood_group_cleansed_Steglitz_Zehlendorf  VIF =  1.25
# neighbourhood_group_cleansed_Pankow  VIF =  1.31
# neighbourhood_group_cleansed_Marzahn_Hellersdorf  VIF =  1.16
# neighbourhood_group_cleansed_Reinickendorf  VIF =  1.04
# neighbourhood_group_cleansed_Spandau  VIF =  1.11
# is_location_exact_t  VIF =  1.03
# room_type_Private_room  VIF =  1.46
# room_type_Shared_room  VIF =  1.04
# bed_type_Couch  VIF =  3.65
# bed_type_Futon  VIF =  9.43
# bed_type_Pull_out_Sofa  VIF =  17.84
# bed_type_Real_Bed  VIF =  28.4
# instant_bookable_t  VIF =  1.12
# cancellation_policy_moderate  VIF =  1.33
# cancellation_policy_strict_14_with_grace_period  VIF =  1.45
# cancellation_policy_super_strict_30  VIF =  2.47
# cancellation_policy_super_strict_60  VIF =  1.01
# Laptop_friendly_workspace_True  VIF =  1.11
# TV_True  VIF =  1.19
# Hot_water_True  VIF =  1.28
# Family_friendly_True  VIF =  1.24
# Smoking_allowed_True  VIF =  1.09
# year_2009  VIF =  9.35
# year_2010  VIF =  48.99
# year_2011  VIF =  193.07
# year_2012  VIF =  365.35
# year_2013  VIF =  528.47
# year_2014  VIF =  678.59
# year_2015  VIF =  780.65
# year_2016  VIF =  635.75
# year_2017  VIF =  469.37
# year_2018  VIF =  315.67

# %%
lm2 = smf.ols(formula= 'price ~ accommodates+guests_included+availability_30+availability_90+availability_365+number_of_reviews+review_scores_rating+review_scores_cleanliness+review_scores_communication+review_scores_location+review_scores_value+calculated_host_listings_count+dist_average+bathrooms+bedrooms+host_is_superhost_t+neighbourhood_group_cleansed_Mitte+neighbourhood_group_cleansed_Neukölln+neighbourhood_group_cleansed_Tempelhof_Schöneberg+neighbourhood_group_cleansed_Steglitz_Zehlendorf+neighbourhood_group_cleansed_Pankow+neighbourhood_group_cleansed_Reinickendorf+neighbourhood_group_cleansed_Spandau+room_type_Private_room+room_type_Shared_room+bed_type_Couch+bed_type_Futon+bed_type_Pull_out_Sofa+bed_type_Real_Bed+instant_bookable_t+cancellation_policy_moderate+cancellation_policy_strict_14_with_grace_period+cancellation_policy_super_strict_30+Laptop_friendly_workspace_True+TV_True+Family_friendly_True+Smoking_allowed_True+year_2009+year_2010+year_2011+year_2012+year_2013+year_2014+year_2015+year_2016+year_2017+year_2018',data = Train).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     308.4
# Date:                Sat, 06 Feb 2021   Prob (F-statistic):               0.00
# Time:                        04:20:51   Log-Likelihood:                -64726.
# No. Observations:               14023   AIC:                         1.295e+05
# Df Residuals:                   13975   BIC:                         1.299e+05
# Df Model:                          47
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                            -7.8826     15.884     -0.496      0.620     -39.018      23.253
# accommodates                                          6.5371      0.234     27.921      0.000       6.078       6.996
# guests_included                                       4.8966      0.332     14.763      0.000       4.246       5.547
# availability_30                                       0.4211      0.049      8.582      0.000       0.325       0.517
# availability_90                                       0.0839      0.018      4.754      0.000       0.049       0.118
# availability_365                                      0.0042      0.003      1.560      0.119      -0.001       0.009
# number_of_reviews                                    -0.0545      0.007     -8.134      0.000      -0.068      -0.041
# review_scores_rating                                  0.2134      0.049      4.370      0.000       0.118       0.309
# review_scores_cleanliness                             1.9264      0.297      6.481      0.000       1.344       2.509
# review_scores_communication                          -0.5365      0.411     -1.307      0.191      -1.341       0.268
# review_scores_location                                2.9120      0.344      8.468      0.000       2.238       3.586
# review_scores_value                                  -3.4658      0.393     -8.809      0.000      -4.237      -2.695
# calculated_host_listings_count                       -0.3789      0.110     -3.453      0.001      -0.594      -0.164
# dist_average                                         -2.0137      0.121    -16.643      0.000      -2.251      -1.777
# bathrooms                                            10.4886      0.785     13.370      0.000       8.951      12.026
# bedrooms                                              8.8323      0.462     19.129      0.000       7.927       9.737
# host_is_superhost_t                                   3.9522      0.688      5.741      0.000       2.603       5.302
# neighbourhood_group_cleansed_Mitte                   -2.1466      0.676     -3.174      0.002      -3.472      -0.821
# neighbourhood_group_cleansed_Neukölln                -1.0859      0.634     -1.713      0.087      -2.328       0.156
# neighbourhood_group_cleansed_Tempelhof_Schöneberg    -2.9907      0.867     -3.451      0.001      -4.689      -1.292
# neighbourhood_group_cleansed_Steglitz_Zehlendorf     -2.9016      1.716     -1.691      0.091      -6.264       0.461
# neighbourhood_group_cleansed_Pankow                  -0.9851      0.646     -1.525      0.127      -2.251       0.281
# neighbourhood_group_cleansed_Reinickendorf          -12.8753      2.141     -6.013      0.000     -17.072      -8.678
# neighbourhood_group_cleansed_Spandau                 -8.5973      3.449     -2.493      0.013     -15.357      -1.837
# room_type_Private_room                              -20.1251      0.501    -40.197      0.000     -21.106     -19.144
# room_type_Shared_room                               -23.6808      2.142    -11.054      0.000     -27.880     -19.482
# bed_type_Couch                                      -10.4223      6.986     -1.492      0.136     -24.116       3.271
# bed_type_Futon                                      -10.8179      6.296     -1.718      0.086     -23.159       1.523
# bed_type_Pull_out_Sofa                               -9.9013      6.124     -1.617      0.106     -21.905       2.102
# bed_type_Real_Bed                                    -7.9225      5.958     -1.330      0.184     -19.600       3.755
# instant_bookable_t                                    1.0456      0.474      2.204      0.028       0.116       1.975
# cancellation_policy_moderate                          0.5608      0.507      1.106      0.269      -0.433       1.555
# cancellation_policy_strict_14_with_grace_period       2.0139      0.560      3.597      0.000       0.916       3.111
# cancellation_policy_super_strict_30                 -20.4018      6.208     -3.287      0.001     -32.569      -8.234
# Laptop_friendly_workspace_True                        1.1783      0.444      2.656      0.008       0.309       2.048
# TV_True                                               5.0095      0.455     11.006      0.000       4.117       5.902
# Family_friendly_True                                  1.3229      0.484      2.734      0.006       0.375       2.271
# Smoking_allowed_True                                 -2.0852      0.525     -3.970      0.000      -3.115      -1.056
# year_2009                                            21.2630     14.991      1.418      0.156      -8.121      50.647
# year_2010                                            14.7832     14.311      1.033      0.302     -13.268      42.834
# year_2011                                            15.9535     14.200      1.123      0.261     -11.881      43.788
# year_2012                                            16.8705     14.186      1.189      0.234     -10.936      44.676
# year_2013                                            16.3824     14.181      1.155      0.248     -11.413      44.178
# year_2014                                            15.5312     14.179      1.095      0.273     -12.262      43.324
# year_2015                                            13.7944     14.179      0.973      0.331     -13.999      41.587
# year_2016                                            13.8381     14.181      0.976      0.329     -13.958      41.634
# year_2017                                            15.0963     14.186      1.064      0.287     -12.711      42.904
# year_2018                                            15.8699     14.195      1.118      0.264     -11.955      43.695
# ==============================================================================
# Omnibus:                     6159.616   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56269.788
# Skew:                           1.878   Prob(JB):                         0.00
# Kurtosis:                      12.066   Cond. No.                     3.48e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.48e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## Prediction on Training and Test set

y_pred_1_Train = lm1.fittedvalues
y_pred_2_Train = lm2.fittedvalues


y_pred_1_Test = lm1.predict(Test)
y_pred_2_Test = lm2.predict(Test)

# %%
## RMSE Calculation on Training and Test set

from sklearn.metrics import mean_squared_error

print('RMSE on Training Set for Model 1:',mean_squared_error(y_true=Train['price'],y_pred=y_pred_1_Train,squared=False))
print('RMSE on Training Set for Model 2:',mean_squared_error(y_true=Train['price'],y_pred=y_pred_2_Train,squared=False))
# Out:
# RMSE on Training Set for Model 1: 24.45052382928614
# RMSE on Training Set for Model 2: 24.453691525935234

# %%
print('RMSE on Test Set for Model 1:',mean_squared_error(y_true=Test['price'],y_pred=y_pred_1_Test,squared=False))
print('RMSE on Test Set for Model 2:',mean_squared_error(y_true=Test['price'],y_pred=y_pred_2_Test,squared=False))
# Out:
# RMSE on Test Set for Model 1: 23.837732448276228
# RMSE on Test Set for Model 2: 23.839379491468176

# %% [markdown]
# # END
