# %%
import numpy as np
import random
np.random.seed(2)
rand_array = np.random.randn(10)
rand_array
# Out:
# array([-0.41675785, -0.05626683, -2.1361961 ,  1.64027081, -1.79343559,
#        -0.84174737,  0.50288142, -1.24528809, -1.05795222, -0.90900761])

# %%
rand_array[5]

# %%
rand_array[1:4]

# %% [markdown]
# # 2D Arrays

# %%
np.random.seed(2)
rand_matrix = np.random.randint(9,size = (3,3))
rand_matrix
# Out:
# array([[8, 8, 6],
#        [2, 8, 7],
#        [2, 1, 5]])

# %%
#Extract 2nd row?

# %%
#Extract 2nd column?

# %%
#Extract 2nd and 2nd column? - What will be the output
rand_matrix[1,1]
# Out:
# 8

# %%
np.random.seed(2)
rand_matrix1 = np.random.randint(16,size = (4,4))
rand_matrix1
# Out:
# array([[ 8, 15, 13,  8],
#        [ 6, 11,  2, 11],
#        [ 8,  7,  2,  1],
#        [15, 11,  5, 15]])

# %%
#Extract first column and 3rd column
rand_matrix1[: , 0:3:2]
# Out:
# array([[ 8, 13],
#        [ 6,  2],
#        [ 8,  2],
#        [15,  5]])

# %%
mydata.describe().transpose().apply(lambda s: s.apply(lambda x: format(x, '.02f')))

# %% [markdown]
# # Summary of the data
#
# To see the summary of any dataframe we will use describe function.

# %%
#os.chdir('C:\\Users\\MyPC\\Desktop\\DataCamp_exercises\\GL_Mentoring\\Python')

# %%
np_array = np.linspace(0,1,100)
np_array
data_df.describe(percentiles = np_array)
include='all'

# %%
import numpy as np
import pandas as pd

# %%
data_df = pd.read_excel(r"C:\Users\anchhabra\Python_Training_DSBA_GL\Week_2\Food Nutrition (2).xlsx")
data_df.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          78.30     1.62            2.87           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74      NaN            2.34           0.0           0.50
# 4            NaN     3.18            2.79           0.0           0.51
#
#    Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Potassium_(mg)  \
# ...

# %%
data_df.loc[0:6,]
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
# 5    1006             CHEESE,BRIE      48.42         334        20.75
# 6    1007        CHEESE,CAMEMBERT      51.80         300        19.80
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          78.30     1.62            2.87           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74      NaN            2.34           0.0           0.50
# ...

# %%
data_df.iloc[-3:]
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  \
# 597           0.0          13.52            99       2.30               8
# 598           0.0          13.10           134       2.30              10
# 599           0.0           6.70            69       1.18               5
#
#      Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  Copper_mg)  \
# ...

# %%
# data_df.iloc[-3,1]
data_df.loc[597,'Shrt_Desc']
# Out:
# 'INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ CONC,NOT RECON'

# %%
data_df.index[-3]
# Out:
# 597

# %%
data_df.drop(data_df.index[-3])
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 0      1001                                   BUTTER,WITH SALT      15.87
# 1      1002                             BUTTER,WHIPPED,W/ SALT      16.72
# 2      1003                               BUTTER OIL,ANHYDROUS       0.24
# 3      1004                                        CHEESE,BLUE      42.41
# 4      1005                                       CHEESE,BRICK      41.11
# 5      1006                                        CHEESE,BRIE      48.42
# 6      1007                                   CHEESE,CAMEMBERT      51.80
# 7      1008                                     CHEESE,CARAWAY      39.28
# 8      1009                                     CHEESE,CHEDDAR      37.02
# 9      1010                                    CHEESE,CHESHIRE      37.65
# 10     1011                                       CHEESE,COLBY      38.20
# 11     1012                CHEESE,COTTAGE,CRMD,LRG OR SML CURD      79.79
# ...

# %% [markdown]
# # Using the cut function on water variable divide the whole data into 6 bins, list down the summary statistics of all the 6 bins.

# %%
data_bins = data_df.copy()

# %%
data_bins['bins'] = pd.cut(data_bins['Water_(g)'],6, labels =["A", "B", "C","D","E","F"])

# %%
data_bins.head(5)
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...   \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          78.30     1.62            2.87           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74      NaN            2.34           0.0           0.50  ...
# 4            NaN     3.18            2.79           0.0           0.51  ...
#
#    Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  \
# ...

# %%
data_bins["bins"].value_counts()
# Out:
# F    193
# E    175
# A    127
# C     54
# D     41
# B     10
# Name: bins, dtype: int64

# %% [markdown]
# we can either do this in one go, like shown below

# %%
data_bins.groupby("bins").describe().T
# Out:
# bins                             A            B            C            D  \
# Ash_(g)        count    127.000000    10.000000    53.000000    41.000000
#                mean       7.032441     3.925000     3.985094     2.716829
#                std       12.780734     2.586694     1.792142     2.509094
#                min        0.000000     0.090000     0.390000     0.180000
#                25%        2.925000     1.762500     3.180000     0.760000
#                50%        4.000000     4.010000     3.830000     1.580000
#                75%        7.010000     6.302500     4.960000     3.680000
#                max       99.800000     7.180000     8.030000    10.370000
# Calcium_(mg)   count    127.000000    10.000000    54.000000    41.000000
#                mean     618.330709   683.700000   615.018519   310.390244
#                std      530.134186   485.891632   272.904676   309.052170
#                min        0.000000    18.000000    63.000000     0.000000
# ...

# %% [markdown]
# or we can create subsets of the data on the bases of bins

# %%
A=data_bins[data_bins["bins"]=="A"]
B=data_bins[data_bins["bins"]=="B"]
C=data_bins[data_bins["bins"]=="C"]
E=data_bins[data_bins["bins"]=="E"]
F=data_bins[data_bins["bins"]=="F"]
G=data_bins[data_bins["bins"]=="G"]

# %%
A.describe()# You can do for others
# Out:
#             NDB_No   Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   127.000000  127.000000  127.000000   127.000000     127.000000
# mean   2427.000000    5.964094  405.181102    16.981339      16.340157
# std    1006.346851    3.634829  123.142286    15.983079      16.559315
# min    1001.000000    0.200000    0.000000     0.000000       0.000000
# 25%    2003.500000    2.990000  324.000000     9.055000       4.320000
# 50%    2035.000000    5.440000  391.000000    12.010000      12.600000
# 75%    3214.500000    8.460000  505.500000    18.030000      26.855000
# max    3950.000000   16.720000  876.000000    84.080000      99.480000
#
#           Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  127.000000      127.000000    127.000000     127.000000    127.000000
# mean     7.032441       53.572756      9.881102      20.913150    618.330709
# std     12.780734       21.142774     14.068132      23.569114    530.134186
# ...

# %% [markdown]
# OR make loop for it.

# %%
X=[A,B,C,E,F,G]
for i in X:
    print(i.describe())
# Out:
#             NDB_No   Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   127.000000  127.000000  127.000000   127.000000     127.000000
# mean   2427.000000    5.964094  405.181102    16.981339      16.340157
# std    1006.346851    3.634829  123.142286    15.983079      16.559315
# min    1001.000000    0.200000    0.000000     0.000000       0.000000
# 25%    2003.500000    2.990000  324.000000     9.055000       4.320000
# 50%    2035.000000    5.440000  391.000000    12.010000      12.600000
# 75%    3214.500000    8.460000  505.500000    18.030000      26.855000
# max    3950.000000   16.720000  876.000000    84.080000      99.480000
#
#           Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  127.000000      127.000000    127.000000     127.000000    127.000000
# mean     7.032441       53.572756      9.881102      20.913150    618.330709
# std     12.780734       21.142774     14.068132      23.569114    530.134186
# ...

# %%
data_df.describe()
# Out:
#             NDB_No   Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   600.000000  600.000000  600.000000   600.000000     599.000000
# mean   2301.111667   60.353683  187.106667     8.685983       8.882855
# std    1082.604616   31.894651  158.599869    10.950042      12.278978
# min    1001.000000    0.200000    0.000000     0.000000       0.000000
# 25%    1171.750000   39.242500   63.000000     1.707500       0.705000
# 50%    2051.500000   76.160000  106.500000     3.915000       3.490000
# 75%    3190.250000   85.962500  315.750000    12.500000      13.000000
# max    3953.000000   99.900000  876.000000    84.080000      99.480000
#
#           Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  599.000000      600.000000    600.000000     600.000000    600.000000
# mean     2.543105       19.339817      2.578833       9.094000    263.145000
# std      6.489103       21.508136      7.583582      13.912935    376.848952
# ...

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,hue = 'sex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
